# %%
import pandas as pd 
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn import linear_model
#import pylab as plt
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import statsmodels.api as sm
# %matplotlib inline

# %% [markdown]
# ###This notebook will analyze the correlations between resident and working population socio-demographic attributes and  the number of 311 calls by type per capita, at the census tract level

# %%
#Upload the working population attributes, and the resident population attributes at the CT level. Then, merging both datasets
demographics_CT_NYC_residents=pd.read_csv('../datasets/version2/demographics_CT_NYC_residents.csv').drop('Geo_FIPS',axis=1)
demographics_CT_NYC_workers=pd.read_csv('../datasets/version2/demographics_CT_NYC_workers.csv').drop('Geo_FIPS',axis=1)
demographics_CT_NYC=pd.merge(demographics_CT_NYC_residents,demographics_CT_NYC_workers,on='BoroCT2010',how='inner')
print len(demographics_CT_NYC_residents),len(demographics_CT_NYC_workers),len(demographics_CT_NYC)
# Out:
# 2167 2149 2149

# %%
residents_demographics=demographics_CT_NYC_residents.columns[1:]
workers_demographics=demographics_CT_NYC_workers.columns[1:]

# %%
#Upload the 311 calls by type per capita
calls_bytype_normalized=pd.read_csv('../datasets/version2/Call by type with normalization by resident - Census Tract level.csv').drop('Unnamed: 0',axis=1)

# %%
calls_bytype_normalized.head()
# Out:
#    BoroCT2010  AGENCY  APPLIANCE  Adopt-A-Basket  Air Quality  Animal Abuse  \
# 0     1000202     NaN        NaN             NaN     0.000241      0.000120
# 1     1000600     NaN   0.000793             NaN     0.000793      0.000088
# 2     1000700     NaN        NaN             NaN     0.001977      0.000233
# 3     1000800     NaN   0.000536             NaN     0.000643      0.000429
# 4     1000900     NaN        NaN             NaN     0.010745      0.001433
#
#    Animal Facility - No Permit  Animal in a Park  Asbestos  BEST/Site Safety  \
# 0                          NaN               NaN       NaN               NaN
# 1                          NaN               NaN  0.000088          0.000088
# 2                          NaN               NaN  0.000814               NaN
# 3                          NaN          0.000107       NaN          0.000107
# 4                          NaN               NaN  0.001433               NaN
#
#       ...       Vacant Lot   Vending  Violation of Park Rules  WATER LEAK  \
# 0     ...              NaN       NaN                      NaN         NaN
# 1     ...              NaN  0.000176                 0.000088    0.000793
# 2     ...              NaN  0.001628                 0.000116    0.000465
# 3     ...              NaN  0.000321                 0.000107    0.000429
# 4     ...              NaN  0.005731                 0.001433    0.000716
#
#    Water Conservation  Water Quality  Water System  Window Guard  \
# 0            0.000481            NaN      0.002407           NaN
# 1                 NaN       0.000088      0.007486           NaN
# 2                 NaN            NaN      0.004536           NaN
# 3                 NaN       0.000107      0.003536           NaN
# 4            0.001433            NaN      0.027937           NaN
#
#    X-Ray Machine/Equipment  total_calls
# 0                      NaN     0.069812
# 1                      NaN     0.101374
# 2                      NaN     0.189928
# 3                      NaN     0.118397
# 4                      NaN     0.790115
#
# [5 rows x 181 columns]

# %%
#callsbytype_attributes will be a dataframe combining all the information (demographics + calls by type)
callsbytype_attributes=pd.merge(calls_bytype_normalized,demographics_CT_NYC, on='BoroCT2010',how='inner')
print len(callsbytype_attributes), len(calls_bytype_normalized),len(demographics_CT_NYC)
# Out:
# 1977 1978 2149

# %%
regressors=demographics_CT_NYC.columns[1:]  #demographic indicators
types_of_calls=calls_bytype_normalized.columns[1:]  #types of calls

# %%
correlations = pd.DataFrame(index=types_of_calls.values, columns=regressors)
rsqr = pd.DataFrame(index=types_of_calls.values, columns=regressors)

# %%
#this step calculates the relations between each regressor and each type of call. In each iteration, a subset containing just one
#type of call and all the regressor from callsbytype_attributes is taken, then the correlations are calculated for those types of calls
#that are presented in more than 100 census tracts. All the results are saved in a data frame "correlations"
for typeof in types_of_calls:    
    A2=np.append(np.append(regressors,typeof),'BoroCT2010')   #selection of columns
    myframe1=callsbytype_attributes[A2].dropna()              #subseting the dataframe
    if len(myframe1)>100:
        X=myframe1[regressors]
        Y=myframe1[typeof]
        X[typeof]=Y
        Neighcorr = X.corr(method='pearson', min_periods=1)
        for regres in regressors:
            corr_coef=Neighcorr[typeof][:len(regressors)]
            correlations.loc[typeof,regres]=np.float32(corr_coef[regres])
correlations.dropna(inplace=True)
# Out:
# C:\Users\Marco\Anaconda\lib\site-packages\IPython\kernel\__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
correlations
# Out:
#                                         Total Population Population under 18  \
# APPLIANCE                                    -0.04893617          0.09123221
# Air Quality                                   -0.1311951          -0.1597486
# Animal Abuse                                  -0.1599176           -0.124674
# Animal in a Park                              -0.4045841          -0.3297761
# Asbestos                                      -0.2571025          -0.2594378
# BEST/Site Safety                              -0.1084419         -0.06303073
# Beach/Pool/Sauna Complaint                     -0.313353          -0.2804596
# Bike/Roller/Skate Chronic                     -0.3736493          -0.3103774
# Blocked Driveway                              -0.3371037           -0.235086
# Boilers                                       -0.2242482          -0.1551421
# Broken Muni Meter                             -0.1079691          -0.1244847
# Building/Use                                   -0.182324          -0.1306206
# Bus Stop Shelter Placement                    -0.4766877          -0.4631394
# CONSTRUCTION                                  -0.3767233          -0.2847708
# City Vehicle Placard Complaint                -0.3850304          -0.3708078
# Collection Truck Noise                        -0.5699216          -0.3744635
# Construction                                  -0.2629323          -0.2284242
# Consumer Complaint                            -0.1024528         -0.09660307
# Cranes and Derricks                           -0.2819225           -0.251496
# Curb Condition                                -0.3283295          -0.2414445
# DOF Parking - Tax Exemption                   -0.1874325          -0.2183005
# DOF Property - Reduction Issue                -0.2673132          -0.2650287
# DOOR/WINDOW                                  0.005076262           0.1293733
# DPR Internal                                  -0.2789467          -0.2304077
# Damaged Tree                                  -0.3388537          -0.2856362
# Dead Tree                                     -0.2238286          -0.2036542
# Derelict Bicycle                              -0.2435894          -0.3548228
# Derelict Vehicle                              -0.2456518          -0.1903715
# Derelict Vehicles                             -0.2921512          -0.2120823
# Dirty Conditions                              -0.2412262          -0.2075174
# ...                                                  ...                 ...
# Sidewalk Condition                            -0.1667348           -0.184642
# Smoking                                       -0.1703289          -0.1499385
# Snow                                           -0.272353          -0.2384417
# Special Enforcement                            -0.242688          -0.2276629
# Special Projects Inspection Team (SPIT)      -0.08181538         -0.07935503
# Standing Water                                -0.2573992          -0.2161645
# Street Condition                              -0.2206473          -0.2103532
# Street Light Condition                        -0.2154297          -0.1743625
# Street Sign - Damaged                          -0.200035          -0.1704583
# Street Sign - Dangling                        -0.2673343          -0.2373076
# Street Sign - Missing                         -0.2833417          -0.2424559
# Sweeping/Inadequate                           -0.5472557          -0.4641259
# Sweeping/Missed                               -0.3792669          -0.3173196
# Taxi Complaint                                -0.1242338          -0.1492692
# Taxi Report                                   -0.3175176          -0.2742647
# Traffic                                       -0.2124121          -0.2164831
# Traffic Signal Condition                       -0.212583          -0.1679184
# UNSANITARY CONDITION                          0.03513204           0.1396826
# Unleashed Dog                                 -0.3124727          -0.2513038
# Unsanitary Animal Pvt Property                -0.2780614          -0.2519867
# Unsanitary Pigeon Condition                   -0.4569891          -0.3650133
# Urinating in Public                           -0.5836427          -0.5050998
# Vacant Lot                                    -0.3045469          -0.2244209
# Vending                                       -0.1823351          -0.1889655
# Violation of Park Rules                       -0.2871879          -0.2291739
# WATER LEAK                                   0.007763818           0.1011292
# Water Conservation                            -0.3171629          -0.2353249
# Water Quality                                 -0.3537097           -0.319181
# Water System                                   -0.149178          -0.1399926
# total_calls                                   -0.1629194          -0.1514934
#
#                                         population between 18 and 34  \
# APPLIANCE                                                -0.02169963
# Air Quality                                              -0.07646235
# Animal Abuse                                              -0.1244049
# Animal in a Park                                          -0.3195858
# Asbestos                                                   -0.185066
# BEST/Site Safety                                          -0.1173986
# Beach/Pool/Sauna Complaint                                -0.2534644
# Bike/Roller/Skate Chronic                                 -0.2855603
# Blocked Driveway                                          -0.2903207
# Boilers                                                   -0.1613084
# Broken Muni Meter                                         -0.0783769
# Building/Use                                              -0.1730842
# Bus Stop Shelter Placement                                 -0.421152
# CONSTRUCTION                                              -0.3225042
# City Vehicle Placard Complaint                            -0.3294913
# Collection Truck Noise                                    -0.4527574
# Construction                                              -0.2571034
# Consumer Complaint                                       -0.07549359
# Cranes and Derricks                                       -0.2464444
# Curb Condition                                            -0.2754543
# DOF Parking - Tax Exemption                                -0.237945
# DOF Property - Reduction Issue                            -0.2745531
# DOOR/WINDOW                                               0.04121067
# DPR Internal                                              -0.2096137
# Damaged Tree                                              -0.3936779
# Dead Tree                                                 -0.2717437
# Derelict Bicycle                                          -0.0910368
# Derelict Vehicle                                           -0.262844
# Derelict Vehicles                                         -0.2629645
# Dirty Conditions                                          -0.1808014
# ...                                                              ...
# Sidewalk Condition                                        -0.1043643
# Smoking                                                   -0.1278186
# Snow                                                      -0.2886014
# Special Enforcement                                       -0.1989338
# Special Projects Inspection Team (SPIT)                  -0.06149768
# Standing Water                                            -0.2552583
# Street Condition                                          -0.1994611
# Street Light Condition                                    -0.2055322
# Street Sign - Damaged                                     -0.1630366
# Street Sign - Dangling                                    -0.2246326
# Street Sign - Missing                                     -0.2481347
# Sweeping/Inadequate                                       -0.4877694
# Sweeping/Missed                                           -0.3620763
# Taxi Complaint                                           -0.07464543
# Taxi Report                                               -0.2556308
# Traffic                                                   -0.1512226
# Traffic Signal Condition                                  -0.1628217
# UNSANITARY CONDITION                                      0.07393191
# Unleashed Dog                                             -0.3194538
# Unsanitary Animal Pvt Property                            -0.2521684
# Unsanitary Pigeon Condition                               -0.3553203
# Urinating in Public                                       -0.5209255
# Vacant Lot                                                -0.2911756
# Vending                                                   -0.1341922
# Violation of Park Rules                                   -0.2225252
# WATER LEAK                                                0.05069305
# Water Conservation                                        -0.3131799
# Water Quality                                             -0.2954665
# Water System                                              -0.1199168
# total_calls                                              -0.09487624
#
#                                         population between 35 to 64  \
# APPLIANCE                                               -0.08558332
# Air Quality                                              -0.1201185
# Animal Abuse                                             -0.1574432
# Animal in a Park                                         -0.3750168
# Asbestos                                                 -0.2405463
# BEST/Site Safety                                        -0.08349009
# Beach/Pool/Sauna Complaint                               -0.2972949
# Bike/Roller/Skate Chronic                                -0.3479278
# Blocked Driveway                                          -0.308627
# Boilers                                                  -0.2230505
# Broken Muni Meter                                       -0.09714071
# Building/Use                                             -0.1575701
# Bus Stop Shelter Placement                               -0.4411018
# CONSTRUCTION                                             -0.3427171
# City Vehicle Placard Complaint                           -0.3671005
# Collection Truck Noise                                   -0.5552506
# Construction                                             -0.2401518
# Consumer Complaint                                      -0.09799337
# Cranes and Derricks                                      -0.2571969
# Curb Condition                                           -0.3125314
# DOF Parking - Tax Exemption                              -0.1543751
# DOF Property - Reduction Issue                           -0.2271812
# DOOR/WINDOW                                             -0.03627929
# DPR Internal                                              -0.244862
# Damaged Tree                                             -0.2787037
# Dead Tree                                                 -0.173923
# Derelict Bicycle                                         -0.2258899
# Derelict Vehicle                                          -0.214294
# Derelict Vehicles                                        -0.2800674
# Dirty Conditions                                          -0.222182
# ...                                                             ...
# Sidewalk Condition                                       -0.1561276
# Smoking                                                  -0.1578238
# Snow                                                     -0.2289567
# Special Enforcement                                      -0.2236781
# Special Projects Inspection Team (SPIT)                 -0.06945745
# Standing Water                                           -0.2170657
# Street Condition                                         -0.1945484
# Street Light Condition                                   -0.1947029
# Street Sign - Damaged                                    -0.1913403
# Street Sign - Dangling                                   -0.2533935
# Street Sign - Missing                                     -0.262668
# Sweeping/Inadequate                                      -0.5118943
# Sweeping/Missed                                          -0.3434728
# Taxi Complaint                                           -0.1161083
# Taxi Report                                              -0.3034388
# Traffic                                                  -0.1958987
# Traffic Signal Condition                                 -0.2099602
# UNSANITARY CONDITION                                   -0.005831799
# Unleashed Dog                                            -0.2962297
# Unsanitary Animal Pvt Property                           -0.2506658
# Unsanitary Pigeon Condition                              -0.4421974
# Urinating in Public                                      -0.5323943
# Vacant Lot                                               -0.2823091
# Vending                                                  -0.1716665
# Violation of Park Rules                                  -0.2629285
# WATER LEAK                                              -0.02859567
# Water Conservation                                       -0.2805049
# Water Quality                                            -0.3299105
# Water System                                             -0.1359904
# total_calls                                              -0.1581566
#
#                                         population 65 and over   Median Age  \
# APPLIANCE                                           -0.1771873    -0.223451
# Air Quality                                        -0.08949333   0.02924878
# Animal Abuse                                        -0.1348876   0.02386606
# Animal in a Park                                    -0.2552479    0.2792784
# Asbestos                                            -0.1676069   0.02597719
# BEST/Site Safety                                   -0.08587997   0.04558811
# Beach/Pool/Sauna Complaint                          -0.2095557  -0.02712043
# Bike/Roller/Skate Chronic                           -0.2568929   0.05860325
# Blocked Driveway                                    -0.3153269  -0.05206881
# Boilers                                             -0.2056058  -0.01605139
# Broken Muni Meter                                  -0.06176749   0.01839776
# Building/Use                                        -0.1614394    0.0331897
# Bus Stop Shelter Placement                          -0.3453183   -0.0354272
# CONSTRUCTION                                        -0.3000568   0.02530961
# City Vehicle Placard Complaint                       -0.268658 -0.003389849
# Collection Truck Noise                               -0.370941  -0.03600582
# Construction                                        -0.1603905   0.09342817
# Consumer Complaint                                 -0.07280054 -0.008592382
# Cranes and Derricks                                 -0.1826758  -0.05898723
# Curb Condition                                      -0.2297866  0.006020671
# DOF Parking - Tax Exemption                         0.06154131    0.3197948
# DOF Property - Reduction Issue                     -0.09882037    0.2118417
# DOOR/WINDOW                                         -0.1441485    -0.249911
# DPR Internal                                        -0.1955558    0.2487684
# Damaged Tree                                        -0.1342931    0.3375882
# Dead Tree                                          -0.04890949    0.2989062
# Derelict Bicycle                                    -0.2152241  -0.05392569
# Derelict Vehicle                                    -0.1370555    0.1842277
# Derelict Vehicles                                   -0.2290573  0.003966309
# Dirty Conditions                                    -0.2160818 -0.005953962
# ...                                                        ...          ...
# Sidewalk Condition                                  -0.1183922   0.02333728
# Smoking                                              -0.121797   0.03475022
# Snow                                                -0.1306904    0.1478483
# Special Enforcement                                 -0.1442997   0.06335956
# Special Projects Inspection Team (SPIT)            -0.06778093   0.02834466
# Standing Water                                      -0.1592279    0.1215868
# Street Condition                                    -0.1259587    0.1010255
# Street Light Condition                              -0.1332323    0.1204901
# Street Sign - Damaged                               -0.1349543   0.02434848
# Street Sign - Dangling                              -0.1727019   0.06346526
# Street Sign - Missing                                -0.190668   0.05867909
# Sweeping/Inadequate                                 -0.3749546    0.1573572
# Sweeping/Missed                                     -0.2193065   0.08547428
# Taxi Complaint                                     -0.07867015   0.03125422
# Taxi Report                                         -0.2089611 -0.008638845
# Traffic                                             -0.1495766   0.05708246
# Traffic Signal Condition                            -0.1704466  0.007986658
# UNSANITARY CONDITION                                -0.1220291   -0.2526344
# Unleashed Dog                                       -0.1772498    0.0508883
# Unsanitary Animal Pvt Property                      -0.1853923    0.1319817
# Unsanitary Pigeon Condition                         -0.3465506  -0.05156032
# Urinating in Public                                 -0.3837452    0.2258033
# Vacant Lot                                          -0.2285507   0.03386676
# Vending                                             -0.1062764   0.02278462
# Violation of Park Rules                             -0.1983044    0.1712331
# WATER LEAK                                          -0.1276698   -0.2170491
# Water Conservation                                  -0.2211533    0.1054372
# Water Quality                                       -0.2244243   0.09446638
# Water System                                        -0.1065959    0.0520893
# total_calls                                         -0.1622799  -0.02943682
#
#                                         Population white population black  \
# APPLIANCE                                     -0.3157638        0.3153812
# Air Quality                                  -0.01066402        -0.082498
# Animal Abuse                                   -0.112034       -0.0106088
# Animal in a Park                              -0.2260042      -0.07950515
# Asbestos                                     -0.06225354       -0.1121555
# BEST/Site Safety                             -0.09897998      -0.05863992
# Beach/Pool/Sauna Complaint                    -0.1990505      -0.07235558
# Bike/Roller/Skate Chronic                     -0.2047907       -0.1188947
# Blocked Driveway                              -0.2886278       -0.1237376
# Boilers                                       -0.1510461      -0.06291664
# Broken Muni Meter                            -0.01555661      -0.06132157
# Building/Use                                  -0.1750722      -0.06997525
# Bus Stop Shelter Placement                    -0.2995893       -0.1902374
# CONSTRUCTION                                  -0.1663917      -0.05929881
# City Vehicle Placard Complaint                -0.2085666       -0.1472844
# Collection Truck Noise                        -0.3595323       -0.1015164
# Construction                                 -0.09496818       -0.1900811
# Consumer Complaint                           -0.04666938      -0.04208251
# Cranes and Derricks                           -0.2227312      -0.08573566
# Curb Condition                                -0.1436851       -0.1287789
# DOF Parking - Tax Exemption                    0.0735388       -0.2713332
# DOF Property - Reduction Issue               -0.08362799       -0.0917685
# DOOR/WINDOW                                   -0.2963484        0.3099949
# DPR Internal                                  -0.1478655      -0.03586787
# Damaged Tree                                 -0.02117247       -0.1821855
# Dead Tree                                     0.04359542       -0.1360558
# Derelict Bicycle                             -0.04595463       -0.2013841
# Derelict Vehicle                             -0.09217332      -0.08243819
# Derelict Vehicles                             -0.2081918        0.0090707
# Dirty Conditions                              -0.1424176      -0.02366525
# ...                                                  ...              ...
# Sidewalk Condition                           -0.01870244      -0.09930689
# Smoking                                      -0.07716681      -0.06040719
# Snow                                          0.04212232       -0.1862092
# Special Enforcement                          -0.09759697        -0.110148
# Special Projects Inspection Team (SPIT)      -0.05168738      -0.04979769
# Standing Water                             -0.0005230287        -0.151813
# Street Condition                             0.007781205       -0.1487808
# Street Light Condition                       -0.07127566      -0.08278878
# Street Sign - Damaged                        -0.06091424      -0.08622149
# Street Sign - Dangling                        -0.1263337      -0.07201228
# Street Sign - Missing                         -0.1228424       -0.0910274
# Sweeping/Inadequate                           -0.2305739      -0.02634978
# Sweeping/Missed                               -0.1567944      -0.08735519
# Taxi Complaint                              -0.005390191      -0.07752509
# Taxi Report                                   -0.1969948       -0.1120776
# Traffic                                      -0.06637659       -0.1069522
# Traffic Signal Condition                     -0.06298923       -0.0862523
# UNSANITARY CONDITION                          -0.2855088         0.345001
# Unleashed Dog                                 -0.0465506       -0.1461666
# Unsanitary Animal Pvt Property               -0.09391224      -0.07974008
# Unsanitary Pigeon Condition                   -0.2460028      -0.09837072
# Urinating in Public                           -0.2305756       -0.1655075
# Vacant Lot                                    -0.0920753      -0.05899366
# Vending                                      -0.04950601      -0.09301607
# Violation of Park Rules                       -0.1457837      -0.08802962
# WATER LEAK                                    -0.2854908        0.3556452
# Water Conservation                            -0.1137727      -0.05856838
# Water Quality                                 -0.1388017       -0.1346271
# Water System                                 -0.04463666      -0.07448424
# total_calls                                   -0.1059086      -0.01675926
#
#                                         Population asian population hispanic  \
# APPLIANCE                                     -0.2585762           0.1601884
# Air Quality                                  -0.05588896         -0.08762877
# Animal Abuse                                  -0.1047837         -0.04783551
# Animal in a Park                              -0.1467235          -0.2243854
# Asbestos                                      -0.0986386          -0.1635135
# BEST/Site Safety                              0.01796603         -0.05656989
# Beach/Pool/Sauna Complaint                    -0.1463024          -0.1310474
# Bike/Roller/Skate Chronic                     -0.1138539          -0.1980514
# Blocked Driveway                              0.01399293         -0.09698976
# Boilers                                       -0.1306512         -0.01558822
# Broken Muni Meter                            -0.03793297         -0.07772898
# Building/Use                                  0.06685739         -0.09734245
# Bus Stop Shelter Placement                    -0.2337665          -0.2348168
# CONSTRUCTION                                  -0.1652811          -0.2078134
# City Vehicle Placard Complaint                -0.2380185          -0.1991871
# Collection Truck Noise                        -0.2613002          -0.2790531
# Construction                                0.0005278249          -0.1555177
# Consumer Complaint                             -0.028529         -0.04852578
# Cranes and Derricks                            -0.145897          -0.1552029
# Curb Condition                               -0.09219935          -0.1629756
# DOF Parking - Tax Exemption                   -0.1612121           -0.277688
# DOF Property - Reduction Issue                -0.1005164          -0.1654264
# DOOR/WINDOW                                    -0.267383           0.2206034
# DPR Internal                                 -0.07414772          -0.1737212
# Damaged Tree                                 -0.05090839          -0.3191844
# Dead Tree                                    -0.08298811           -0.232132
# Derelict Bicycle                             -0.08804997          -0.1767201
# Derelict Vehicle                             -0.08809916          -0.1606949
# Derelict Vehicles                             -0.1453874          -0.1474927
# Dirty Conditions                              -0.1168337          -0.1234187
# ...                                                  ...                 ...
# Sidewalk Condition                           -0.06169692           -0.117802
# Smoking                                      -0.04576918         -0.08676002
# Snow                                          -0.1016832          -0.2392727
# Special Enforcement                          -0.07157914          -0.1245416
# Special Projects Inspection Team (SPIT)      0.005093712         -0.05471083
# Standing Water                                -0.1242927          -0.1867962
# Street Condition                             -0.07169895          -0.1751386
# Street Light Condition                       -0.06737357          -0.1352827
# Street Sign - Damaged                        -0.06073605          -0.1343375
# Street Sign - Dangling                       -0.09907635          -0.1640868
# Street Sign - Missing                         -0.0946568          -0.1698659
# Sweeping/Inadequate                           -0.2496332          -0.3787932
# Sweeping/Missed                               -0.1380202          -0.2605689
# Taxi Complaint                               -0.04252805         -0.09092665
# Taxi Report                                   -0.1502435          -0.1602577
# Traffic                                      -0.07796839          -0.1324932
# Traffic Signal Condition                     -0.07483477          -0.1138058
# UNSANITARY CONDITION                          -0.2375246           0.2195282
# Unleashed Dog                                 -0.1560466          -0.1950447
# Unsanitary Animal Pvt Property                -0.1371235          -0.1606017
# Unsanitary Pigeon Condition                   -0.1719964          -0.2586794
# Urinating in Public                           -0.1904418          -0.3241047
# Vacant Lot                                    -0.1598327          -0.1964287
# Vending                                      -0.05112496          -0.1147691
# Violation of Park Rules                       -0.1071188          -0.1260634
# WATER LEAK                                    -0.2638883           0.1740242
# Water Conservation                            -0.1527665          -0.1961614
# Water Quality                                   -0.13732          -0.2098395
# Water System                                 -0.06941167         -0.07067244
# total_calls                                   -0.1179404         -0.04643578
#
#                                              ...       \
# APPLIANCE                                    ...
# Air Quality                                  ...
# Animal Abuse                                 ...
# Animal in a Park                             ...
# Asbestos                                     ...
# BEST/Site Safety                             ...
# Beach/Pool/Sauna Complaint                   ...
# Bike/Roller/Skate Chronic                    ...
# Blocked Driveway                             ...
# Boilers                                      ...
# Broken Muni Meter                            ...
# Building/Use                                 ...
# Bus Stop Shelter Placement                   ...
# CONSTRUCTION                                 ...
# City Vehicle Placard Complaint               ...
# Collection Truck Noise                       ...
# Construction                                 ...
# Consumer Complaint                           ...
# Cranes and Derricks                          ...
# Curb Condition                               ...
# DOF Parking - Tax Exemption                  ...
# DOF Property - Reduction Issue               ...
# DOOR/WINDOW                                  ...
# DPR Internal                                 ...
# Damaged Tree                                 ...
# Dead Tree                                    ...
# Derelict Bicycle                             ...
# Derelict Vehicle                             ...
# Derelict Vehicles                            ...
# Dirty Conditions                             ...
# ...                                          ...
# Sidewalk Condition                           ...
# Smoking                                      ...
# Snow                                         ...
# Special Enforcement                          ...
# Special Projects Inspection Team (SPIT)      ...
# Standing Water                               ...
# Street Condition                             ...
# Street Light Condition                       ...
# Street Sign - Damaged                        ...
# Street Sign - Dangling                       ...
# Street Sign - Missing                        ...
# Sweeping/Inadequate                          ...
# Sweeping/Missed                              ...
# Taxi Complaint                               ...
# Taxi Report                                  ...
# Traffic                                      ...
# Traffic Signal Condition                     ...
# UNSANITARY CONDITION                         ...
# Unleashed Dog                                ...
# Unsanitary Animal Pvt Property               ...
# Unsanitary Pigeon Condition                  ...
# Urinating in Public                          ...
# Vacant Lot                                   ...
# Vending                                      ...
# Violation of Park Rules                      ...
# WATER LEAK                                   ...
# Water Conservation                           ...
# Water Quality                                ...
# Water System                                 ...
# total_calls                                  ...
#
#                                         rent from 1500 to 2000_n  \
# APPLIANCE                                            -0.06221574
# Air Quality                                             0.316083
# Animal Abuse                                            0.206778
# Animal in a Park                                    -0.009833428
# Asbestos                                               0.4135983
# BEST/Site Safety                                      0.00246423
# Beach/Pool/Sauna Complaint                             0.3663477
# Bike/Roller/Skate Chronic                              0.2201548
# Blocked Driveway                                     -0.05426386
# Boilers                                                0.3662274
# Broken Muni Meter                                      0.3298675
# Building/Use                                           0.0124521
# Bus Stop Shelter Placement                             0.1314622
# CONSTRUCTION                                         -0.03022342
# City Vehicle Placard Complaint                       -0.02251176
# Collection Truck Noise                                 -0.179693
# Construction                                           0.1250039
# Consumer Complaint                                     0.3130044
# Cranes and Derricks                                    0.2681289
# Curb Condition                                       -0.03477493
# DOF Parking - Tax Exemption                            0.2666115
# DOF Property - Reduction Issue                       -0.01184739
# DOOR/WINDOW                                          -0.07974821
# DPR Internal                                         -0.05473677
# Damaged Tree                                         -0.08706825
# Dead Tree                                            -0.04887408
# Derelict Bicycle                                       0.1441912
# Derelict Vehicle                                     -0.03926186
# Derelict Vehicles                                    -0.01356325
# Dirty Conditions                                       0.1487388
# ...                                                          ...
# Sidewalk Condition                                     0.3679828
# Smoking                                                0.2928145
# Snow                                                  0.04753374
# Special Enforcement                                    0.3597337
# Special Projects Inspection Team (SPIT)               0.07796198
# Standing Water                                         0.2002385
# Street Condition                                       0.3282026
# Street Light Condition                                 0.0188225
# Street Sign - Damaged                                  0.2641801
# Street Sign - Dangling                                 0.2404258
# Street Sign - Missing                                  0.1501048
# Sweeping/Inadequate                                  -0.05831193
# Sweeping/Missed                                      -0.06023315
# Taxi Complaint                                         0.4160058
# Taxi Report                                            0.3278705
# Traffic                                                0.3177293
# Traffic Signal Condition                               0.1169537
# UNSANITARY CONDITION                                 -0.08456289
# Unleashed Dog                                        -0.08936731
# Unsanitary Animal Pvt Property                         -0.035777
# Unsanitary Pigeon Condition                           0.01192907
# Urinating in Public                                   0.04873343
# Vacant Lot                                           -0.01271835
# Vending                                                0.3614953
# Violation of Park Rules                                0.1745658
# WATER LEAK                                            -0.0899597
# Water Conservation                                    0.07592545
# Water Quality                                          0.1814357
# Water System                                           0.3102347
# total_calls                                            0.3433898
#
#                                         rent 2000 or more_n cars per capita  \
# APPLIANCE                                       -0.05547306     -0.06021428
# Air Quality                                       0.3868295       0.3108918
# Animal Abuse                                      0.2600855       0.1985361
# Animal in a Park                               -0.001578846     -0.01085701
# Asbestos                                          0.4302745       0.4052279
# BEST/Site Safety                                0.006998943   -0.0003643166
# Beach/Pool/Sauna Complaint                        0.4704273       0.3494998
# Bike/Roller/Skate Chronic                         0.3196613       0.2148879
# Blocked Driveway                                -0.06894189     -0.05999095
# Boilers                                           0.3367481       0.3551326
# Broken Muni Meter                                 0.3976311       0.3244813
# Building/Use                                     0.02055873     0.008997031
# Bus Stop Shelter Placement                       0.08206482       0.1171228
# CONSTRUCTION                                    -0.01766773     -0.03365694
# City Vehicle Placard Complaint                  -0.02846287     -0.02159693
# Collection Truck Noise                           -0.1827541      -0.1813127
# Construction                                     0.07345404       0.1059226
# Consumer Complaint                                0.3455472        0.308682
# Cranes and Derricks                                0.378319        0.261616
# Curb Condition                                  -0.04143768     -0.03485899
# DOF Parking - Tax Exemption                       0.3056026       0.2640229
# DOF Property - Reduction Issue                 -0.009808972     -0.01445707
# DOOR/WINDOW                                     -0.08077195     -0.07738084
# DPR Internal                                    -0.05175139     -0.05261211
# Damaged Tree                                    -0.09300101     -0.09189612
# Dead Tree                                       -0.05259482     -0.05164313
# Derelict Bicycle                                  0.1820399       0.1458936
# Derelict Vehicle                                -0.04537575     -0.04338703
# Derelict Vehicles                               -0.03482883     -0.01764561
# Dirty Conditions                                  0.1644959       0.1442114
# ...                                                     ...             ...
# Sidewalk Condition                                0.4334651        0.362719
# Smoking                                            0.343133        0.284466
# Snow                                             0.05214516      0.04459887
# Special Enforcement                               0.4114469       0.3500269
# Special Projects Inspection Team (SPIT)           0.1040756      0.07620992
# Standing Water                                    0.2100842       0.1923181
# Street Condition                                  0.3810345       0.3210963
# Street Light Condition                         -0.002579235      0.01716065
# Street Sign - Damaged                             0.3116575       0.2620726
# Street Sign - Dangling                            0.2848379       0.2373754
# Street Sign - Missing                             0.1676312       0.1476867
# Sweeping/Inadequate                             -0.03853665     -0.06599346
# Sweeping/Missed                                 -0.07266542     -0.06132426
# Taxi Complaint                                     0.508051       0.4097703
# Taxi Report                                       0.4081942       0.3230578
# Traffic                                           0.3870463       0.3129508
# Traffic Signal Condition                         0.09650076       0.1168026
# UNSANITARY CONDITION                            -0.08739985     -0.08144593
# Unleashed Dog                                    -0.1014381     -0.08843472
# Unsanitary Animal Pvt Property                  -0.03049888     -0.03681582
# Unsanitary Pigeon Condition                     -0.01087053     0.004822255
# Urinating in Public                              0.05626074       0.0472526
# Vacant Lot                                      -0.01768341     -0.01602689
# Vending                                            0.431649        0.357343
# Violation of Park Rules                           0.2174197       0.1683339
# WATER LEAK                                      -0.07936568      -0.0840435
# Water Conservation                                0.1024797      0.07082122
# Water Quality                                     0.2406424       0.1731829
# Water System                                      0.3559842       0.3049527
# total_calls                                       0.4035316       0.3383439
#
#                                         transportation car_n  \
# APPLIANCE                                        -0.05852809
# Air Quality                                        0.3076583
# Animal Abuse                                       0.2041224
# Animal in a Park                                 -0.01392429
# Asbestos                                           0.4083745
# BEST/Site Safety                                 0.004385602
# Beach/Pool/Sauna Complaint                         0.3647395
# Bike/Roller/Skate Chronic                          0.2123729
# Blocked Driveway                                 -0.05347112
# Boilers                                            0.3710732
# Broken Muni Meter                                  0.3223951
# Building/Use                                      0.01367839
# Bus Stop Shelter Placement                          0.141548
# CONSTRUCTION                                     -0.02604423
# City Vehicle Placard Complaint                   -0.02786832
# Collection Truck Noise                              -0.17372
# Construction                                       0.1194866
# Consumer Complaint                                 0.3091862
# Cranes and Derricks                                0.2632955
# Curb Condition                                   -0.03625196
# DOF Parking - Tax Exemption                        0.2558316
# DOF Property - Reduction Issue                  -0.008676869
# DOOR/WINDOW                                      -0.07628712
# DPR Internal                                     -0.05684897
# Damaged Tree                                     -0.07816114
# Dead Tree                                        -0.04308368
# Derelict Bicycle                                   0.1312497
# Derelict Vehicle                                 -0.03434024
# Derelict Vehicles                                -0.01165274
# Dirty Conditions                                   0.1477545
# ...                                                      ...
# Sidewalk Condition                                  0.361376
# Smoking                                            0.2881146
# Snow                                              0.05280728
# Special Enforcement                                0.3528351
# Special Projects Inspection Team (SPIT)           0.07595236
# Standing Water                                      0.209221
# Street Condition                                   0.3268404
# Street Light Condition                            0.02149815
# Street Sign - Damaged                              0.2614822
# Street Sign - Dangling                             0.2367242
# Street Sign - Missing                              0.1463552
# Sweeping/Inadequate                              -0.04818592
# Sweeping/Missed                                   -0.0576575
# Taxi Complaint                                     0.4079511
# Taxi Report                                        0.3214919
# Traffic                                            0.3082154
# Traffic Signal Condition                           0.1114072
# UNSANITARY CONDITION                             -0.08239615
# Unleashed Dog                                    -0.08421648
# Unsanitary Animal Pvt Property                   -0.02677337
# Unsanitary Pigeon Condition                       0.01049554
# Urinating in Public                               0.04749444
# Vacant Lot                                     -0.0003812169
# Vending                                            0.3529298
# Violation of Park Rules                            0.1640329
# WATER LEAK                                       -0.08692208
# Water Conservation                                 0.0797227
# Water Quality                                      0.1886515
# Water System                                       0.3067855
# total_calls                                         0.337216
#
#                                         transportation public_n  \
# APPLIANCE                                           -0.05939202
# Air Quality                                            0.327308
# Animal Abuse                                          0.2118881
# Animal in a Park                                   -0.009552199
# Asbestos                                              0.4136639
# BEST/Site Safety                                   0.0009890901
# Beach/Pool/Sauna Complaint                            0.3713082
# Bike/Roller/Skate Chronic                             0.2334847
# Blocked Driveway                                    -0.06170259
# Boilers                                               0.3576264
# Broken Muni Meter                                      0.341125
# Building/Use                                         0.01115323
# Bus Stop Shelter Placement                            0.1124538
# CONSTRUCTION                                        -0.03153533
# City Vehicle Placard Complaint                       -0.0225194
# Collection Truck Noise                               -0.1826958
# Construction                                         0.09975665
# Consumer Complaint                                    0.3211839
# Cranes and Derricks                                   0.2850732
# Curb Condition                                       -0.0350823
# DOF Parking - Tax Exemption                            0.273438
# DOF Property - Reduction Issue                        -0.013792
# DOOR/WINDOW                                           -0.077603
# DPR Internal                                        -0.05345577
# Damaged Tree                                        -0.09433448
# Dead Tree                                           -0.05336843
# Derelict Bicycle                                      0.1544662
# Derelict Vehicle                                    -0.04482028
# Derelict Vehicles                                   -0.01946642
# Dirty Conditions                                      0.1500025
# ...                                                         ...
# Sidewalk Condition                                     0.379886
# Smoking                                               0.2994521
# Snow                                                 0.04488782
# Special Enforcement                                   0.3650886
# Special Projects Inspection Team (SPIT)              0.08189262
# Standing Water                                        0.1946967
# Street Condition                                      0.3346445
# Street Light Condition                                0.0138908
# Street Sign - Damaged                                 0.2743081
# Street Sign - Dangling                                0.2486349
# Street Sign - Missing                                 0.1534131
# ...
# Animal Abuse                                          0.2582746
# Animal in a Park                                   -0.005513895
# Asbestos                                               0.432309
# BEST/Site Safety                                    0.004020446
# Beach/Pool/Sauna Complaint                            0.4357856
# Bike/Roller/Skate Chronic                             0.3146734
# Blocked Driveway                                    -0.07099938
# Boilers                                               0.3455972
# Broken Muni Meter                                     0.3964308
# Building/Use                                         0.01744537
# Bus Stop Shelter Placement                           0.08300689
# CONSTRUCTION                                        -0.02294469
# City Vehicle Placard Complaint                      -0.02449242
# Collection Truck Noise                               -0.1849147
# Construction                                         0.07110778
# Consumer Complaint                                    0.3542339
# Cranes and Derricks                                   0.3692908
# Curb Condition                                      -0.03957848
# DOF Parking - Tax Exemption                           0.3003957
# DOF Property - Reduction Issue                      -0.01242981
# DOOR/WINDOW                                         -0.08027838
# DPR Internal                                        -0.05041863
# Damaged Tree                                         -0.1059809
# Dead Tree                                           -0.06177614
# Derelict Bicycle                                      0.1927248
# Derelict Vehicle                                    -0.05201731
# Derelict Vehicles                                   -0.03236704
# Dirty Conditions                                      0.1663047
# ...                                                         ...
# Sidewalk Condition                                    0.4350741
# Smoking                                               0.3496159
# Snow                                                 0.04702388
# Special Enforcement                                    0.407608
# Special Projects Inspection Team (SPIT)               0.1006077
# Standing Water                                        0.2017066
# Street Condition                                      0.3772103
# Street Light Condition                             -0.001010036
# Street Sign - Damaged                                 0.3144608
# Street Sign - Dangling                                0.2857104
# Street Sign - Missing                                 0.1716941
# Sweeping/Inadequate                                 -0.07864328
# Sweeping/Missed                                     -0.07691496
# Taxi Complaint                                         0.505026
# Taxi Report                                           0.4101875
# Traffic                                               0.3856809
# Traffic Signal Condition                              0.1087693
# UNSANITARY CONDITION                                -0.08571939
# Unleashed Dog                                       -0.09472591
# Unsanitary Animal Pvt Property                      -0.04164232
# Unsanitary Pigeon Condition                        -0.006628532
# Urinating in Public                                  0.05147956
# Vacant Lot                                          -0.02895519
# Vending                                               0.4346068
# Violation of Park Rules                               0.2090401
# WATER LEAK                                           -0.0797567
# Water Conservation                                    0.0907075
# Water Quality                                         0.2144837
# Water System                                          0.3594478
# total_calls                                           0.4051861
#
#                                         transportation walk_n  \
# APPLIANCE                                         -0.06042486
# Air Quality                                         0.3840179
# Animal Abuse                                        0.2566679
# Animal in a Park                                 -0.004663805
# Asbestos                                            0.4314796
# BEST/Site Safety                                  0.003473524
# Beach/Pool/Sauna Complaint                          0.4396614
# Bike/Roller/Skate Chronic                           0.3118528
# Blocked Driveway                                   -0.0713654
# Boilers                                             0.3433422
# Broken Muni Meter                                   0.3947539
# Building/Use                                       0.01656302
# Bus Stop Shelter Placement                         0.07906227
# CONSTRUCTION                                      -0.02460549
# City Vehicle Placard Complaint                    -0.02487572
# Collection Truck Noise                             -0.1860167
# Construction                                       0.07187209
# Consumer Complaint                                   0.350057
# Cranes and Derricks                                 0.3644768
# Curb Condition                                    -0.04006335
# DOF Parking - Tax Exemption                         0.3015709
# DOF Property - Reduction Issue                    -0.01293741
# DOOR/WINDOW                                       -0.08103956
# DPR Internal                                      -0.05022691
# Damaged Tree                                       -0.1064114
# Dead Tree                                         -0.06199057
# Derelict Bicycle                                    0.1899302
# Derelict Vehicle                                  -0.05243161
# Derelict Vehicles                                 -0.03255769
# Dirty Conditions                                    0.1643004
# ...                                                       ...
# Sidewalk Condition                                  0.4317661
# Smoking                                             0.3463038
# Snow                                               0.04672299
# Special Enforcement                                 0.4060288
# Special Projects Inspection Team (SPIT)            0.09994977
# Standing Water                                      0.2005238
# Street Condition                                     0.375037
# Street Light Condition                           -0.001554205
# Street Sign - Damaged                               0.3115852
# Street Sign - Dangling                              0.2834636
# Street Sign - Missing                               0.1696635
# Sweeping/Inadequate                               -0.08041331
# Sweeping/Missed                                   -0.07717514
# Taxi Complaint                                      0.5018573
# Taxi Report                                         0.4065385
# Traffic                                             0.3835249
# Traffic Signal Condition                            0.1089011
# UNSANITARY CONDITION                              -0.08637989
# Unleashed Dog                                     -0.09777986
# Unsanitary Animal Pvt Property                    -0.04325179
# Unsanitary Pigeon Condition                      -0.006253903
# Urinating in Public                                0.05125229
# Vacant Lot                                        -0.03047239
# Vending                                             0.4322466
# Violation of Park Rules                             0.2132095
# WATER LEAK                                        -0.08091039
# Water Conservation                                 0.08919291
# Water Quality                                       0.2140983
# Water System                                         0.356161
# total_calls                                         0.4021024
#
#                                         transportation other means_n  \
# APPLIANCE                                                 -0.0550869
# Air Quality                                                0.3745116
# Animal Abuse                                                0.253405
# Animal in a Park                                        -0.007708736
# Asbestos                                                   0.4311003
# BEST/Site Safety                                         0.006277266
# Beach/Pool/Sauna Complaint                                 0.4341353
# Bike/Roller/Skate Chronic                                  0.2945626
# Blocked Driveway                                         -0.06735839
# Boilers                                                    0.3557507
# Broken Muni Meter                                          0.3857258
# Building/Use                                              0.01822741
# Bus Stop Shelter Placement                                0.09314629
# CONSTRUCTION                                             -0.02154896
# City Vehicle Placard Complaint                           -0.02609848
# Collection Truck Noise                                    -0.1845006
# Construction                                              0.07881948
# Consumer Complaint                                         0.3484278
# Cranes and Derricks                                        0.3533678
# Curb Condition                                           -0.03894595
# DOF Parking - Tax Exemption                                0.2936053
# DOF Property - Reduction Issue                           -0.01134101
# DOOR/WINDOW                                              -0.07665212
# DPR Internal                                             -0.05345289
# Damaged Tree                                             -0.09728683
# Dead Tree                                                -0.05541817
# Derelict Bicycle                                           0.1778189
# Derelict Vehicle                                         -0.04681754
# Derelict Vehicles                                        -0.02840579
# Dirty Conditions                                           0.1663035
# ...                                                              ...
# Sidewalk Condition                                         0.4263093
# Smoking                                                    0.3403202
# Snow                                                      0.04906746
# Special Enforcement                                        0.4016293
# Special Projects Inspection Team (SPIT)                   0.09777625
# Standing Water                                             0.2046061
# Street Condition                                           0.3716465
# Street Light Condition                                   0.003599652
# Street Sign - Damaged                                      0.3064537
# Street Sign - Dangling                                     0.2771398
# Street Sign - Missing                                      0.1664367
# Sweeping/Inadequate                                       -0.0550718
# Sweeping/Missed                                           -0.0703682
# Taxi Complaint                                             0.4914777
# Taxi Report                                                0.3953183
# Traffic                                                    0.3741651
# Traffic Signal Condition                                    0.106486
# UNSANITARY CONDITION                                     -0.08315154
# Unleashed Dog                                            -0.09036929
# Unsanitary Animal Pvt Property                           -0.03661476
# Unsanitary Pigeon Condition                             -0.007500855
# Urinating in Public                                       0.05173116
# Vacant Lot                                               -0.01986688
# Vending                                                    0.4220838
# Violation of Park Rules                                    0.1998466
# WATER LEAK                                               -0.07698508
# Water Conservation                                        0.09237447
# Water Quality                                              0.2203963
# Water System                                               0.3536686
# total_calls                                                0.3968144
#
#                                         total workers
# APPLIANCE                                 -0.05904704
# Air Quality                                 0.3176515
# Animal Abuse                                0.2057654
# Animal in a Park                           -0.0121633
# Asbestos                                    0.4097139
# BEST/Site Safety                         0.0006848288
# Beach/Pool/Sauna Complaint                  0.3562052
# Bike/Roller/Skate Chronic                   0.2224175
# Blocked Driveway                          -0.06006614
# Boilers                                     0.3619102
# Broken Muni Meter                           0.3320444
# Building/Use                               0.01053653
# Bus Stop Shelter Placement                  0.1194348
# CONSTRUCTION                              -0.03290018
# City Vehicle Placard Complaint            -0.02323664
# Collection Truck Noise                     -0.1811534
# Construction                                0.1063208
# Consumer Complaint                          0.3166634
# Cranes and Derricks                         0.2728365
# Curb Condition                            -0.03563756
# DOF Parking - Tax Exemption                    0.2652
# DOF Property - Reduction Issue            -0.01350912
# DOOR/WINDOW                               -0.07649823
# DPR Internal                              -0.05456299
# Damaged Tree                              -0.09223719
# Dead Tree                                 -0.05198877
# Derelict Bicycle                             0.147344
# Derelict Vehicle                          -0.04323044
# Derelict Vehicles                           -0.017157
# Dirty Conditions                            0.1478149
# ...                                               ...
# Sidewalk Condition                          0.3710346
# Smoking                                     0.2934705
# Snow                                        0.0454762
# Special Enforcement                         0.3576484
# Special Projects Inspection Team (SPIT)    0.07823495
# Standing Water                              0.1957155
# Street Condition                            0.3283215
# Street Light Condition                     0.01686552
# Street Sign - Damaged                       0.2685609
# Street Sign - Dangling                      0.2429677
# Street Sign - Missing                       0.1508079
# Sweeping/Inadequate                       -0.06879164
# Sweeping/Missed                           -0.06234351
# Taxi Complaint                               0.419716
# Taxi Report                                 0.3331659
# Traffic                                       0.31959
# Traffic Signal Condition                    0.1165297
# UNSANITARY CONDITION                      -0.08103118
# Unleashed Dog                             -0.08708503
# Unsanitary Animal Pvt Property            -0.03691538
# Unsanitary Pigeon Condition               0.005687825
# Urinating in Public                        0.04726837
# Vacant Lot                                -0.01580602
# Vending                                     0.3660323
# Violation of Park Rules                     0.1706033
# WATER LEAK                                -0.08269555
# Water Conservation                         0.07367747
# Water Quality                               0.1773377
# Water System                                0.3123456
# total_calls                                 0.3462633
#
# [129 rows x 128 columns]

# %%
correlations.to_csv('../outputs/correlations_CT.csv')

# %% [markdown]
# ###now some visualizations of the correlations:

# %%
matrix=correlations.as_matrix()
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.set_aspect('equal')
#plt.imshow(matrix.astype(np.float32))
plt.imshow(matrix.astype(np.float32), interpolation='nearest', cmap=plt.cm.Oranges, 
          aspect='auto') 
plt.colorbar()
plt.show()

# %% [markdown]
# This plot shows how high the coefficients are in the matrix (the horizontal axis represents the regressors, while the vertical axis represents the different type of calls). It can be seen that on the right half of the plot the colors are darker in opposite to the light colors of the other half.
#
# The right half belongs to the regressors associated with working population, while the left half shows the coefficients for the resident population

# %%
matrix=np.abs(correlations.as_matrix())
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.set_aspect('equal')
#plt.imshow(matrix.astype(np.float32))
plt.imshow(matrix.astype(np.float32), interpolation='nearest', cmap=plt.cm.Oranges, 
          aspect='auto') 
plt.colorbar()
plt.show()

# %% [markdown]
# This plot is similar to the previous one, however this one shows the absolute value of the coefficients. It still can be seen that for some types of complains, the colors in the right half (working population demographics) are darker which in this case says that the correlations between demographic indicators of the working population and types of complains per capita are stronger than the resident demographics

# %%
matrix=np.abs(correlations.as_matrix())
matrix_t=matrix.astype(np.float32)
A=plt.hist(matrix_t.ravel(), bins=80, fc='k', ec='k')

# %% [markdown]
# Histogram that represents the behavior of the absolute values of the correlation coefficients between all the demographic attributes and all the types of complains. Most of the coefficients' absolute values are between 0.0 and 0.1. However, there are a considerable number of coefficients that are higher than those

# %%
resident_attributes_corr=correlations[residents_demographics]
matrix_residents=resident_attributes_corr.as_matrix()
matrix_residents_t=matrix_residents.astype(np.float32)
A=plt.hist(matrix_residents_t.ravel(), bins=80, fc='k', ec='k')

# %% [markdown]
# Histogram that represents the behavior of the correlation coefficients between the demographic attributes of the RESIDENTS and all the types of complains. The coefficients seem to be normally distributed but notoriously skewed towards the negative side

# %%
resident_attributes_corr=correlations[residents_demographics]
matrix_residents=np.abs(resident_attributes_corr).as_matrix()
matrix_residents_t=matrix_residents.astype(np.float32)
A=plt.hist(matrix_residents_t.ravel(), bins=80, fc='k', ec='k')

# %% [markdown]
# Histogram that represents the behavior of the ABSOLUTE VALUES of the correlation coefficients between the demographic attributes of the RESIDENTS and all the types of complains.

# %%
workers_attributes_corr=correlations[workers_demographics]
matrix_workers=workers_attributes_corr.as_matrix()
matrix_workers_t=matrix_workers.astype(np.float32)
A=plt.hist(matrix_workers_t.ravel(), bins=80, fc='k', ec='k')

# %% [markdown]
# Histogram that represents the behavior of the correlation coefficients between the demographic attributes of the WORKERS and all the types of complains. The coefficients seem to be greater compared to the ones obtained for the resident demographics

# %%
workers_attributes_corr=correlations[workers_demographics]
matrix_workers=np.abs(workers_attributes_corr).as_matrix()
matrix_workers_t=matrix_workers.astype(np.float32)
A=plt.hist(matrix_workers_t.ravel(), bins=80, fc='k', ec='k')

# %% [markdown]
# Histogram that represents the behavior of the absolute values of the correlation coefficients between the demographic attributes of the WORKERS and all the types of complains. The coefficients seem to be greater compared to the ones obtained for the resident demographics
