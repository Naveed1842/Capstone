# %%
import pandas as pd 
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn import linear_model
#import pylab as plt
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import statsmodels.api as sm
# %matplotlib inline

# %% [markdown]
# ###This notebook will focus on the analytical part of the 311 demographics analysis: that is, multilinear regressions between resident and working population socio-demographic attributes and  the number of 311 calls by type per capita, at the NTA level will be performed and analyzed

# %%
#Upload the working population attributes, and the resident population attributes at the CT level.
#We keep both datasets separated in order to generate separate regressions per type of features
demographics_NTA_NYC_residents=pd.read_csv('demographics_nta_NYC_residents_compiled.csv').drop(['Unnamed: 0', 'Unnamed: 0.1'],axis=1)
demographics_NTA_NYC_workers=pd.read_csv('demographics_nta_NYC_workers_compiled.csv').drop(['Unnamed: 0', 'Unnamed: 0.1'],axis=1)
demographics_NTA_NYC=pd.merge(demographics_NTA_NYC_residents,demographics_NTA_NYC_workers,on='Neighborhood',how='inner')
print len(demographics_NTA_NYC_residents),len(demographics_NTA_NYC_workers),len(demographics_NTA_NYC)
# Out:
# 195 194 194

# %%
#Upload the 311 calls by type, normalized by total resident population
calls_bytype_normalized=pd.read_csv('Call by type with normalization by resident - NTA level.csv').drop('Unnamed: 0', axis=1)

# %%
#Delete the total population from the dataset since we are not going to use it
del(calls_bytype_normalized['Total Population'])

# %%
#Upload the 311 calls by type, non-normalized and the total worker poulation

calls_bytype_nonnormalized=pd.read_csv('Call by type without normalization - NTA level.csv').drop('Unnamed: 0', axis=1)
workers = pd.read_csv('demographics_NTA_NYC_workers.csv')

# %%
workers = workers[['Neighborhood', 'total workers']]

# %%
calls_bytype_nonnormalized = pd.merge(calls_bytype_nonnormalized, workers, on='Neighborhood')

# %%
#Normalizing the total calls by type per working population
calls_bytype_normalized_workers = calls_bytype_nonnormalized[calls_bytype_nonnormalized.columns[1:]].astype(float).div(calls_bytype_nonnormalized['total workers'].astype(float), axis=0)

# %%
calls_bytype_normalized_workers['Neighborhood'] = calls_bytype_nonnormalized['Neighborhood']

# %%
#Delete the total population from the dataset since we are not going to use it
del(calls_bytype_normalized_workers['total workers'])

# %%
#callsbytype_attributes will be a dataframe combining all the information (demographics + calls by type)
#we created to separate frames, one for residents and one for workers
callsbytype_attributes_residents=pd.merge(calls_bytype_normalized,demographics_NTA_NYC_residents, on='Neighborhood',how='inner')
callsbytype_attributes_workers=pd.merge(calls_bytype_normalized_workers,demographics_NTA_NYC_workers, on='Neighborhood',how='inner')
print len(callsbytype_attributes_residents), len(callsbytype_attributes_workers)
# Out:
# 190 190

# %%
types_of_calls=calls_bytype_normalized.columns[:-2]  #types of calls
#calls_bytype_normalized.columns[:-3]

# %%
#Defining  a list of rgeressors
regressors=[u'Population under 18', u'population between 18 and 34',
       u'population between 35 to 64', u'population 65 and over',
       u'Population white', u'population black', u'Population asian',
       u'population hispanic', u'population other race',
       u'family households', u'nonfamily households',
       u'population education high school', u'population education bachelors',
       u'population education masters', u'population education phd',
        u'owner  occupied units',
       u'renter occupied units', u'transportation car', u'number of cars',
       u'transportation public', u'tranportation motorcycle',
        u'household income form 10 to 40',
       u'household income form 40 to 75', u'household income 75 and above',
       u'house value for 20 to 100', u'house value for 100 to 500',
       u'house value 500 or more', u'rent bewteen 300 and 1000',
       u'rent bewteen 1000 and 2000', u'rent 2000 or more',
       u'Transportation Other means', u'population between 18 and 34_n',
       u'population between 35 to 64_n', u'population 65 and over_n',
       u'Population white_n', u'population black_n', u'Population asian_n',
       u'population hispanic_n', u'population other _n',
       u'family households_n', u'nonfamily households_n',
       u'population education high school_n',
       u'population education bachelors_n', u'population education masters_n',
       u'population education phd_n', u'household income less than 10_n',
       u'owner  occupied units_n', u'renter occupied units_n',
       u'transportation car_n', u'transportation public_n',
       u'tranportation motorcycle_n', 
       u'household income form 10 to 40_n',
       u'household income form 40 to 75_n', u'household income 75 and above_n',
       u'house value for 20 to 100_n', u'house value for 100 to 500_n',
       u'house value 500 or more_n', u'rent bewteen 300 and 1000_n',
       u'rent bewteen 1000 and 2000_n', u'Transportation Other means_n']

# %%
#Defining the selected features for the innitial resident OLS regression
#we will use this innitial regression to determine a selected list of types of complaints 
#that meet a certain threadshold to then perform a selective regression by feature types
resident_features = [u'Population under 18', u'population between 18 and 34',
       u'population between 35 to 64', u'population 65 and over', u'Population white', u'population black', u'Population asian',
       u'population hispanic', u'population other race', u'family households', u'nonfamily households', u'population education high school', 
       u'population education bachelors', u'population education masters', u'population education phd', 'owner  occupied units',  
       u'renter occupied units', u'transportation car', u'transportation public', 'tranportation motorcycle', 
       u'Transportation Other means', u'number of cars', u'household income form 10 to 40', u'household income form 40 to 75', 
       u'household income 75 and above', u'house value for 20 to 100', u'house value for 100 to 500',
       u'house value 500 or more', u'rent bewteen 300 and 1000', u'rent bewteen 1000 and 2000', u'rent 2000 or more']

# %%
#Defining the selected features for the innitial workers OLS regression
#we will use this innitial regression to determine a selected list of types of complaints 
#that meet a certain threadshold to then perform a selective regression by feature types
workers_features = [u'population between 18 and 34_n',
       u'population between 35 to 64_n', u'population 65 and over_n', u'Population white_n', u'population black_n', u'Population asian_n',
       u'population hispanic_n', u'population other _n', u'family households_n', u'nonfamily households_n', u'population education high school_n', u'population education bachelors_n', u'population education masters_n', 
       u'population education phd_n', 'owner  occupied units_n',  u'renter occupied units_n', u'transportation car_n', u'transportation public_n',
       u'tranportation motorcycle_n', u'Transportation Other means_n', u'household income form 10 to 40_n', u'household income form 40 to 75_n', 
       u'household income 75 and above_n', u'house value for 20 to 100_n', u'house value for 100 to 500_n', u'house value 500 or more_n', 
       u'rent bewteen 300 and 1000_n', u'rent bewteen 1000 and 2000_n', u'rent 2000 or more_n']

# %%
#This is the list of selected feature types for the second step for the resident group
age_residents=[u'Population under 18', u'population between 18 and 34',
       u'population between 35 to 64', u'population 65 and over']

race_residents=[u'Population white', u'population black', u'Population asian',
       u'population hispanic', u'population other race']

typeof_household_residents=[u'family households', u'nonfamily households']
education_residents= [u'population education high school', u'population education bachelors', u'population education masters', 
                      u'population education phd']
ownorrent_residents = ['owner  occupied units',  u'renter occupied units']
transportationtype_residents = [u'transportation car', u'transportation public', 'tranportation motorcycle',
                              'Transportation Other means', u'number of cars']
income_residents = [u'household income form 10 to 40', u'household income form 40 to 75', u'household income 75 and above']
housing_values_residents = [u'house value for 20 to 100', u'house value for 100 to 500',
       u'house value 500 or more']
rent_residents=[u'rent bewteen 300 and 1000',u'rent bewteen 1000 and 2000', u'rent 2000 or more']
variable_groups_residents=['age_residents','race_residents','typeof_household_residents',
                          'education_residents','ownorrent_residents','transportationtype_residents',
                          'income_residents','housing_values_residents','rent_residents']

# %%
#This is the list of selected feature types for the second step for the workers group
age_workers=[u'population between 18 and 34_n',
       u'population between 35 to 64_n', u'population 65 and over_n']

race_workers=[u'Population white_n', u'population black_n', u'Population asian_n',
       u'population hispanic_n', u'population other _n']

typeof_household_workers=[u'family households_n', u'nonfamily households_n']
education_workers= [u'population education high school_n', u'population education bachelors_n', u'population education masters_n', 
                      u'population education phd_n']
ownorrent_workers = ['owner  occupied units_n',  u'renter occupied units_n']
transportationtype_workers = [u'transportation car_n', u'transportation public_n', 'tranportation motorcycle_n',
                              'Transportation Other means_n']
income_workers = [u'household income form 10 to 40_n', u'household income form 40 to 75_n', u'household income 75 and above_n']
housing_values_workers = [u'house value for 20 to 100_n', u'house value for 100 to 500_n',
       u'house value 500 or more_n']       
rent_workers= [ u'rent bewteen 300 and 1000_n',
       u'rent bewteen 1000 and 2000_n', u'rent 2000 or more_n'] 
variable_groups_workers=['age_workers','race_workers','typeof_household_workers','education_workers','ownorrent_workers',
                        'transportationtype_workers','income_workers','housing_values_workers','rent_workers']

# %% [markdown]
# Lets Consider different groups of population $g=1,2,…,n$ (based on our demographic indicators) and let:
#
#
# $Pr(a,g)$ - the total number of residents in the location $a$ of group $g$
#
# while $Pc(a,g)$ the number of commuters.
#
# Let the unknown (subject to fit) complaining behavior be defined by the average number of complains of type $t$ per resident of group $g$ within his/her place of residency be $rc(g,t)$
#
# Let also, $wc(g,t)$ be the number of complains of type $t$ per commuter of type $g$.
#
# Then the total observed number of complains of type $t$ in the area $a$ is:
#
# $$C(a,t)=\sum_{g,t} Pr(a,g) \ rc(g,t) + \sum_{g,t} Pc(a,g) \ wc(g,t) \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \  \text{(1)}$$
#
# Then we know $Pr(a,g)$ and $Pc(a,g)$ (those are our regressors), we know the output variable $C(a,t)$ from 311 statistics. We need to fit the $rc(g,t)$, $wc(g,t)$ - slope coefficients of the multivariate linear regression.
#
# This will give us complaining behavior per people of different groups and it will be distinguished by the complaining mode - while at home and while on the way.

# %% [markdown]
# ###we will procced as follows:
#
# STEP 1) Lasso regression:
#
# Regressors:
#
# $Pr(a,g)$ - the total number of residents in the location $a$ of group $g$.
#
# $Pc(a,g)$  number of commuters in the location a of group $g$
#
# Target variable to be fit: $rc(g,t)$ -   average number of complains of type $t$ per resident of group $g$                                                      within his/her place of residency
#
# STEP 2) predict the number of complains per capita $wc(g,t)$ from the results of step 1, using equation $(1)$
#
# Using the predicted value $rc(g,t)$ in each area, we are able to get a $wc(g,t)$ prediction (from the formula of the observed total calls by type $C(a,t)$ variable)

# %%
#FIRST, I WILL RUN OLS OVER EVERY TYPE OF COMPLAIN
ols_coefficients_dict={}
for typeof in types_of_calls:
    ols_coefficients_dict[typeof]={}
    A2=np.append(np.append(resident_features ,typeof),'Neighborhood')   #selection of columns
    myframe1=callsbytype_attributes_residents[A2].dropna() 
    if len(myframe1)>50:
        for data_group in variable_groups_residents:
            ols_coefficients_dict[typeof][data_group]={}
            #ols_coefficients_dict[typeof]['coefficients']={}
            #ols_coefficients_dict[typeof]['interval']={}
            features=eval(data_group)           
            A2=np.append(np.append(features ,typeof),'Neighborhood')   #selection of columns
            myframe1=callsbytype_attributes[A2].dropna() 
            X=myframe1[features]
            Y=myframe1[typeof]
            ordinary_LS=sm.OLS(Y, X).fit()
            ols_coefficients_dict[typeof][data_group]['coefficients']=ordinary_LS.params
            ols_coefficients_dict[typeof][data_group]['interval']=ordinary_LS.conf_int()
            ols_coefficients_dict[typeof][data_group]['Rsquared']=ordinary_LS.rsquared

# %%
#EXAMPLE OF THE OUTCOME
ols_coefficients_dict['Noise - Commercial']['age_residents']
# Out:
# {'Rsquared': 0.31423003142503847,
#  'coefficients': Population under 18            -4.937346e-07
#  population between 18 and 34    9.214939e-07
#  population between 35 to 64    -1.589607e-07
#  population 65 and over         -6.199498e-08
#  dtype: float64,
#  'interval':                                          0             1
#  Population under 18          -8.121159e-07 -1.753533e-07
#  population between 18 and 34  5.615133e-07  1.281475e-06
#  population between 35 to 64  -6.473967e-07  3.294754e-07
#  population 65 and over       -8.520514e-07  7.280614e-07}

# %%
len(ols_coefficients_dict)
# Out:
# 178

# %%
#NOW, RUN OLS OVER EVERY TYPE OF COMPLAIN WITH AN R2 HIGHER THAN 0.2 TO SUBSET THE TYPES OF 
#COMPLAINTS WE'RE USING
ols_coefficients_dict={}
for typeof in types_of_calls:
    ols_coefficients_dict[typeof]={}
    A2=np.append(np.append(resident_features ,typeof),'Neighborhood')   #selection of columns
    myframe1=callsbytype_attributes_residents[A2].dropna() 
    if len(myframe1)>50:
        for data_group in variable_groups_residents:
            ols_coefficients_dict[typeof][data_group]={}
            #ols_coefficients_dict[typeof]['coefficients']={}
            #ols_coefficients_dict[typeof]['interval']={}
            features=eval(data_group)           
            A2=np.append(np.append(features ,typeof),'Neighborhood')   #selection of columns
            myframe1=callsbytype_attributes[A2].dropna() 
            X=myframe1[features]
            Y=myframe1[typeof]
            ordinary_LS=sm.OLS(Y, X).fit()
            rsq=ordinary_LS.rsquared
            if rsq>=0.2:
                ols_coefficients_dict[typeof][data_group]['coefficients']=ordinary_LS.params
                ols_coefficients_dict[typeof][data_group]['interval']=ordinary_LS.conf_int()
                ols_coefficients_dict[typeof][data_group]['Rsquared']=rsq
ols_coefficients_filtered={}
for typeof in ols_coefficients_dict.keys():
    if len(ols_coefficients_dict[typeof])>0:
        ols_coefficients_filtered[typeof]=ols_coefficients_dict[typeof]

# %%
len(ols_coefficients_filtered)
# Out:
# 133

# %% [markdown]
# Now, from that dictionary, we want to obtain just the coefficients that fall inside the confidence intervals

# %%
ols_coefficients_filtered
# Out:
# {'APPLIANCE': {'age_residents': {'Rsquared': 0.56932135113683935,
#    'coefficients': Population under 18             1.151141e-07
#    population between 18 and 34    6.144492e-08
#    population between 35 to 64    -2.206819e-08
#    population 65 and over         -8.533714e-08
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18           7.157245e-08  1.586558e-07
#    population between 18 and 34  1.231965e-08  1.105702e-07
#    population between 35 to 64  -8.869380e-08  4.455742e-08
#    population 65 and over       -1.932822e-07  2.260794e-08},
#   'education_residents': {'Rsquared': 0.47522673186489783,
#    'coefficients': population education high school    1.499077e-07
#    population education bachelors     -2.658516e-08
#    population education masters       -7.520183e-08
#    population education phd            5.118561e-07
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school  1.138464e-07  1.859690e-07
#    population education bachelors   -1.417400e-07  8.856962e-08
#    population education masters     -3.158599e-07  1.654562e-07
#    population education phd         -1.389606e-07  1.162673e-06},
#   'housing_values_residents': {'Rsquared': 0.20483189273089153,
#    'coefficients': house value for 20 to 100     7.648353e-07
#    house value for 100 to 500    1.324643e-07
#    house value 500 or more       2.262092e-08
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100   1.828884e-07  1.346782e-06
#    house value for 100 to 500  4.275550e-08  2.221731e-07
#    house value 500 or more    -5.047251e-08  9.571436e-08},
#   'income_residents': {'Rsquared': 0.62091790400679336,
#    'coefficients': household income form 10 to 40    3.620261e-07
#    household income form 40 to 75   -1.543169e-07
#    household income 75 and above    -3.683597e-08
#    dtype: float64,
#    'interval':                                            0             1
#    household income form 10 to 40  2.566058e-07  4.674465e-07
#    household income form 40 to 75 -3.335007e-07  2.486693e-08
#    household income 75 and above  -7.714213e-08  3.470191e-09},
#   'ownorrent_residents': {'Rsquared': 0.52091258118414019,
#    'coefficients': owner  occupied units   -5.874534e-08
#    renter occupied units    1.059979e-07
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units -9.596077e-08 -2.152992e-08
#    renter occupied units  8.811619e-08  1.238797e-07},
#   'race_residents': {'Rsquared': 0.67691282056567526,
#    'coefficients': Population white         5.006937e-09
#    population black         3.754884e-08
#    Population asian        -1.757378e-08
#    population hispanic      5.465991e-08
#    population other race   -3.598400e-08
#    dtype: float64,
#    'interval':                                   0             1
#    Population white      -2.780230e-09  1.279410e-08
#    population black       2.844674e-08  4.665093e-08
#    Population asian      -3.654356e-08  1.395993e-09
#    population hispanic    4.480166e-08  6.451816e-08
#    population other race -1.151219e-07  4.315389e-08},
#   'rent_residents': {'Rsquared': 0.63453618487771557,
#    'coefficients': rent bewteen 300 and 1000     1.845406e-07
#    rent bewteen 1000 and 2000    8.502196e-08
#    rent 2000 or more            -9.373097e-08
#    dtype: float64,
#    'interval':                                        0             1
#    rent bewteen 300 and 1000   1.354103e-07  2.336709e-07
#    rent bewteen 1000 and 2000  4.947353e-08  1.205704e-07
#    rent 2000 or more          -1.404008e-07 -4.706112e-08},
#   'transportationtype_residents': {'Rsquared': 0.46187113396517709,
#    'coefficients': transportation car           -1.447697e-07
#    transportation public         1.108088e-07
#    tranportation motorcycle     -1.359030e-05
#    Transportation Other means   -7.887710e-08
#    number of cars                1.708299e-07
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -5.521428e-07  2.626035e-07
#    transportation public       8.143889e-08  1.401788e-07
#    tranportation motorcycle   -2.234929e-05 -4.831317e-06
#    Transportation Other means -1.600774e-07  2.323226e-09
#    number of cars             -3.077582e-07  6.494180e-07},
#   'typeof_household_residents': {'Rsquared': 0.46468101408706586,
#    'coefficients': family households       1.083308e-07
#    nonfamily households   -1.256445e-08
#    dtype: float64,
#    'interval':                                  0             1
#    family households     8.029770e-08  1.363640e-07
#    nonfamily households -4.785789e-08  2.272900e-08}},
#  'Air Quality': {'age_residents': {'Rsquared': 0.30820938505027162,
#    'coefficients': Population under 18            -9.046539e-08
#    population between 18 and 34    1.306419e-07
#    population between 35 to 64    -2.823683e-08
#    population 65 and over          7.460926e-08
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18          -1.469846e-07 -3.394615e-08
#    population between 18 and 34  6.687484e-08  1.944090e-07
#    population between 35 to 64  -1.147199e-07  5.824622e-08
#    population 65 and over       -6.550762e-08  2.147261e-07},
#   'education_residents': {'Rsquared': 0.32646809749707406,
#    'coefficients': population education high school   -3.617137e-08
#    population education bachelors      1.149195e-07
#    population education masters        1.879235e-07
#    population education phd           -8.542622e-07
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school -7.801362e-08  5.670875e-09
#    population education bachelors   -1.869577e-08  2.485348e-07
#    population education masters     -9.131450e-08  4.671615e-07
#    population education phd         -1.609411e-06 -9.911385e-08},
#   'housing_values_residents': {'Rsquared': 0.23271127004135261,
#    'coefficients': house value for 20 to 100     2.139079e-07
#    house value for 100 to 500   -1.196953e-08
#    house value 500 or more       2.119577e-07
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100  -3.715838e-07  7.993996e-07
#    house value for 100 to 500 -1.022246e-07  7.828556e-08
#    house value 500 or more     1.384190e-07  2.854964e-07},
#   'income_residents': {'Rsquared': 0.31913349308347183,
#    'coefficients': household income form 10 to 40    1.592446e-07
#    household income form 40 to 75   -2.832240e-07
#    household income 75 and above     1.593920e-07
#    dtype: float64,
#    'interval':                                            0             1
#    household income form 10 to 40  1.454198e-08  3.039472e-07
#    household income form 40 to 75 -5.291762e-07 -3.727188e-08
#    household income 75 and above   1.040667e-07  2.147172e-07},
#   'ownorrent_residents': {'Rsquared': 0.25389359262500955,
#    'coefficients': owner  occupied units    4.363477e-08
#    renter occupied units    4.568392e-08
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units -3.932625e-09  9.120217e-08
#    renter occupied units  2.282810e-08  6.853973e-08},
#   'race_residents': {'Rsquared': 0.25453195050054289,
#    'coefficients': Population white         3.295457e-08
#    population black         4.232449e-09
#    Population asian         3.150865e-10
#    population hispanic      9.025118e-09
#    population other race    3.483184e-08
#    dtype: float64,
#    'interval':                                   0             1
#    Population white       2.083999e-08  4.506914e-08
#    population black      -9.927774e-09  1.839267e-08
#    Population asian      -2.919640e-08  2.982657e-08
#    population hispanic   -6.311470e-09  2.436171e-08
#    population other race -8.828383e-08  1.579475e-07},
#   'rent_residents': {'Rsquared': 0.32856530122306948,
#    'coefficients': rent bewteen 300 and 1000     4.260580e-08
#    rent bewteen 1000 and 2000    1.567214e-08
#    rent 2000 or more             2.182785e-07
#    dtype: float64,
#    'interval':                                        0             1
#    rent bewteen 300 and 1000  -2.559931e-08  1.108109e-07
#    rent bewteen 1000 and 2000 -3.367791e-08  6.502220e-08
#    rent 2000 or more           1.534892e-07  2.830679e-07},
#   'transportationtype_residents': {'Rsquared': 0.34020177161804377,
#    'coefficients': transportation car           -2.984119e-07
#    transportation public        -5.803812e-09
#    tranportation motorcycle      6.498330e-06
#    Transportation Other means    2.502278e-07
#    number of cars                3.787178e-07
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -7.603978e-07  1.635739e-07
#    transportation public      -3.911114e-08  2.750351e-08
#    tranportation motorcycle   -3.434900e-06  1.643156e-05
#    Transportation Other means  1.581417e-07  3.423140e-07
#    number of cars             -1.640302e-07  9.214658e-07},
#   'typeof_household_residents': {'Rsquared': 0.3088761883937895,
#    'coefficients': family households      -1.632369e-08
#    nonfamily households    1.220769e-07
#    dtype: float64,
#    'interval':                                  0             1
#    family households    -4.894770e-08  1.630031e-08
#    nonfamily households  8.100359e-08  1.631502e-07}},
#  'Animal Abuse': {'age_residents': {'Rsquared': 0.31209885609684918,
#    'coefficients': Population under 18             3.460025e-08
#    population between 18 and 34    2.452029e-08
#    population between 35 to 64     1.712806e-08
#    population 65 and over         -8.149811e-09
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18          -2.487105e-08  9.407155e-08
#    population between 18 and 34 -4.259376e-08  9.163434e-08
#    population between 35 to 64  -7.373452e-08  1.079906e-07
#    population 65 and over       -1.551456e-07  1.388460e-07},
#   'education_residents': {'Rsquared': 0.31728262427981313,
#    'coefficients': population education high school    9.198939e-08
#    population education bachelors      2.421163e-08
#    population education masters        5.637789e-08
#    population education phd           -2.978446e-07
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school  4.755064e-08  1.364281e-07
#    population education bachelors   -1.175338e-07  1.659571e-07
#    population education masters     -2.398339e-07  3.525897e-07
#    population education phd         -1.100121e-06  5.044321e-07},
#   'housing_values_residents': {'Rsquared': 0.25738163451926632,
#    'coefficients': house value for 20 to 100     3.137088e-07
#    house value for 100 to 500    2.041760e-07
#    house value 500 or more       5.980538e-08
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100  -2.943864e-07  9.218040e-07
#    house value for 100 to 500  1.104373e-07  2.979146e-07
#    house value 500 or more    -1.657219e-08  1.361830e-07},
#   'income_residents': {'Rsquared': 0.30145730884551425,
#    'coefficients': household income form 10 to 40    1.006263e-07
#    household income form 40 to 75    8.431659e-08
#    household income 75 and above     5.149352e-09
#    dtype: float64,
#    'interval':                                            0             1
#    household income form 10 to 40 -5.407618e-08  2.553288e-07
#    household income form 40 to 75 -1.785004e-07  3.471336e-07
#    household income 75 and above  -5.394885e-08  6.424755e-08},
#   'ownorrent_residents': {'Rsquared': 0.29035945510766115,
#    'coefficients': owner  occupied units    6.727054e-08
#    renter occupied units    4.397782e-08
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units  1.832006e-08  1.162210e-07
#    renter occupied units  2.047035e-08  6.748529e-08},
#   'race_residents': {'Rsquared': 0.32012862339113946,
#    'coefficients': Population white         1.769310e-08
#    population black         2.193592e-08
#    Population asian         2.765162e-09
#    population hispanic      2.803646e-08
#    population other race    2.239534e-08
#    dtype: float64,
#    'interval':                                   0             1
#    Population white       5.480396e-09  2.990581e-08
#    population black       7.664495e-09  3.620735e-08
#    Population asian      -2.698639e-08  3.251671e-08
#    population hispanic    1.257513e-08  4.349779e-08
#    population other race -1.017204e-07  1.465111e-07},
#   'rent_residents': {'Rsquared': 0.27671653141952457,
#    'coefficients': rent bewteen 300 and 1000     8.975723e-08
#    rent bewteen 1000 and 2000    7.702602e-08
#    rent 2000 or more             1.908280e-09
#    dtype: float64,
#    'interval':                                        0             1
#    rent bewteen 300 and 1000   1.509260e-08  1.644219e-07
#    rent bewteen 1000 and 2000  2.295589e-08  1.310961e-07
#    rent 2000 or more          -6.907274e-08  7.288930e-08},
#   'transportationtype_residents': {'Rsquared': 0.32363543166566278,
#    'coefficients': transportation car           -2.808279e-07
#    transportation public         2.609179e-08
#    tranportation motorcycle     -2.173432e-07
#    Transportation Other means    4.260135e-08
#    number of cars                4.545963e-07
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -7.745014e-07  2.128455e-07
#    transportation public      -9.506941e-09  6.169053e-08
#    tranportation motorcycle   -1.083378e-05  1.039910e-05
#    Transportation Other means -5.581870e-08  1.410214e-07
#    number of cars             -1.253853e-07  1.034578e-06},
#   'typeof_household_residents': {'Rsquared': 0.31050090900914051,
#    'coefficients': family households       9.065052e-08
#    nonfamily households   -2.110429e-09
#    dtype: float64,
#    'interval':                                  0             1
#    family households     5.624872e-08  1.250523e-07
#    nonfamily households -4.542059e-08  4.119973e-08}},
#  'Animal in a Park': {'age_residents': {},
#   'education_residents': {},
#   'housing_values_residents': {},
#   'income_residents': {},
#   'ownorrent_residents': {},
#   'race_residents': {},
#   'rent_residents': {},
#   'transportationtype_residents': {},
#   'typeof_household_residents': {}},
#  'Asbestos': {'age_residents': {'Rsquared': 0.39838491490075756,
#    'coefficients': Population under 18            -1.699298e-08
#    population between 18 and 34    2.444844e-08
#    population between 35 to 64     4.387730e-10
#    population 65 and over          1.012742e-08
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18          -2.967271e-08 -4.313239e-09
#    population between 18 and 34  1.010338e-08  3.879350e-08
#    population between 35 to 64  -1.905685e-08  1.993439e-08
#    population 65 and over       -2.196003e-08  4.221488e-08},
#   'education_residents': {'Rsquared': 0.42310765812608686,
#    'coefficients': population education high school    5.676997e-10
#    population education bachelors      9.163158e-09
#    population education masters        7.595442e-08
#    population education phd           -2.185624e-07
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school -8.792451e-09  9.927850e-09
#    population education bachelors   -2.071271e-08  3.903902e-08
#    population education masters      1.334021e-08  1.385686e-07
#    population education phd         -3.876578e-07 -4.946707e-08},
#   'housing_values_residents': {'Rsquared': 0.31443843250158621,
#    'coefficients': house value for 20 to 100     3.069712e-07
#    house value for 100 to 500   -5.240515e-09
#    house value 500 or more       4.313875e-08
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100   5.180952e-08  5.621329e-07
#    house value for 100 to 500 -2.840771e-08  1.792668e-08
#    house value 500 or more     2.507418e-08  6.120332e-08},
#   'income_residents': {'Rsquared': 0.42309501646658276,
#    'coefficients': household income form 10 to 40    4.869196e-08
#    household income form 40 to 75   -6.314207e-08
#    household income 75 and above     3.371467e-08
#    dtype: float64,
#    'interval':                                            0             1
#    household income form 10 to 40  1.658751e-08  8.079641e-08
#    household income form 40 to 75 -1.177475e-07 -8.536656e-09
#    household income 75 and above   2.145021e-08  4.597913e-08},
#   'ownorrent_residents': {'Rsquared': 0.39105343548336424,
#    'coefficients': owner  occupied units    9.066912e-09
#    renter occupied units    1.497134e-08
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units -1.382057e-09  1.951588e-08
#    renter occupied units  9.992155e-09  1.995053e-08},
#   'race_residents': {'Rsquared': 0.36039783485039689,
#    'coefficients': Population white         8.012660e-09
#    population black         3.352179e-09
#    Population asian         1.032832e-09
#    population hispanic      3.678340e-09
#    population other race    1.045327e-09
#    dtype: float64,
#    'interval':                                   0             1
#    Population white       5.295997e-09  1.072932e-08
#    population black       1.528823e-10  6.551475e-09
#    Population asian      -5.571847e-09  7.637511e-09
#    population hispanic    2.561536e-10  7.100527e-09
#    population other race -2.641224e-08  2.850290e-08},
#   'rent_residents': {'Rsquared': 0.42405800324341481,
#    'coefficients': rent bewteen 300 and 1000     1.605288e-08
#    rent bewteen 1000 and 2000    9.964580e-09
#    rent 2000 or more             4.399422e-08
#    dtype: float64,
#    'interval':                                        0             1
#    rent bewteen 300 and 1000   7.492962e-10  3.135647e-08
#    rent bewteen 1000 and 2000 -1.072842e-09  2.100200e-08
#    rent 2000 or more           2.955197e-08  5.843647e-08},
#   'transportationtype_residents': {'Rsquared': 0.42813607943428322,
#    'coefficients': transportation car           -1.046175e-07
#    transportation public         5.381829e-09
#    tranportation motorcycle      1.514810e-06
#    Transportation Other means    4.426107e-08
#    number of cars                1.301128e-07
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -2.092663e-07  3.140344e-11
#    transportation public      -2.088728e-09  1.285239e-08
#    tranportation motorcycle   -7.131205e-07  3.742741e-06
#    Transportation Other means  2.361995e-08  6.490219e-08
#    number of cars              6.857252e-09  2.533683e-07},
#   'typeof_household_residents': {'Rsquared': 0.42862684393971973,
#    'coefficients': family households       7.816991e-10
#    nonfamily households    2.857469e-08
#    dtype: float64,
#    'interval':                                  0             1
#    family households    -6.386095e-09  7.949493e-09
#    nonfamily households  1.957898e-08  3.757040e-08}},
#  'BEST/Site Safety': {'age_residents': {},
#   'education_residents': {},
#   'housing_values_residents': {},
#   'income_residents': {},
#   'ownorrent_residents': {},
#   'race_residents': {},
#   'rent_residents': {},
#   'transportationtype_residents': {},
#   'typeof_household_residents': {}},
#  'Beach/Pool/Sauna Complaint': {'age_residents': {},
#   'education_residents': {},
#   'housing_values_residents': {},
#   'income_residents': {},
#   'ownorrent_residents': {},
#   'race_residents': {},
#   'rent_residents': {},
#   'transportationtype_residents': {},
#   'typeof_household_residents': {}},
#  'Bike/Roller/Skate Chronic': {'age_residents': {},
#   'education_residents': {},
#   'housing_values_residents': {},
#   'income_residents': {},
#   'ownorrent_residents': {},
#   'race_residents': {},
#   'rent_residents': {},
#   'transportationtype_residents': {},
#   'typeof_household_residents': {}},
#  'Blocked Driveway': {'age_residents': {'Rsquared': 0.5260451161109343,
#    'coefficients': Population under 18             2.647586e-07
#    population between 18 and 34   -4.647020e-07
#    population between 35 to 64     9.646257e-07
#    population 65 and over         -1.035395e-06
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18          -7.643910e-08  6.059563e-07
#    population between 18 and 34 -8.497475e-07 -7.965641e-08
#    population between 35 to 64   4.433304e-07  1.485921e-06
#    population 65 and over       -1.878737e-06 -1.920539e-07},
#   'education_residents': {'Rsquared': 0.57828560407275342,
#    'coefficients': population education high school    9.350969e-07
#    population education bachelors      3.956648e-07
#    population education masters       -1.295784e-08
#    population education phd           -3.432647e-06
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school  6.936933e-07  1.176501e-06
#    population education bachelors   -3.743359e-07  1.165666e-06
#    population education masters     -1.622063e-06  1.596147e-06
#    population education phd         -7.790837e-06  9.255426e-07},
#   'housing_values_residents': {'Rsquared': 0.45140601667014968,
#    'coefficients': house value for 20 to 100     1.653453e-06
#    house value for 100 to 500    2.002156e-06
#    house value 500 or more       5.278610e-07
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100  -1.959043e-06  5.265950e-06
#    house value for 100 to 500  1.445285e-06  2.559027e-06
#    house value 500 or more     7.412662e-08  9.815954e-07},
#   'income_residents': {'Rsquared': 0.54386524184212393,
#    'coefficients': household income form 10 to 40   -1.438994e-06
#    household income form 40 to 75    5.004338e-06
#    household income 75 and above    -7.665267e-07
#    dtype: float64,
#    'interval':                                        0             1
#    household income form 10 to 40 -0.000002 -5.749401e-07
#    household income form 40 to 75  0.000004  6.472239e-06
#    household income 75 and above  -0.000001 -4.364479e-07},
#   'ownorrent_residents': {'Rsquared': 0.43981279057047917,
#    'coefficients': owner  occupied units    9.140757e-07
#    renter occupied units    2.045668e-07
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units  6.134698e-07  1.214682e-06
#    renter occupied units  6.020689e-08  3.489267e-07},
#   'race_residents': {'Rsquared': 0.51918779933960879,
#    'coefficients': Population white         6.970016e-08
#    population black         1.638503e-07
#    Population asian         3.925981e-07
#    population hispanic      1.679434e-07
#    population other race    3.965437e-07
#    dtype: float64,
#    'interval':                                   0             1
#    Population white      -1.286959e-09  1.406873e-07
#    population black       8.089669e-08  2.468038e-07
#    Population asian       2.196654e-07  5.655308e-07
#    population hispanic    7.807342e-08  2.578133e-07
#    population other race -3.248866e-07  1.117974e-06},
#   'rent_residents': {'Rsquared': 0.48967332309676015,
#    'coefficients': rent bewteen 300 and 1000    -4.603866e-07
#    rent bewteen 1000 and 2000    1.581781e-06
#    rent 2000 or more            -5.653894e-07
#    dtype: float64,
#    'interval':                                        0             1
#    rent bewteen 300 and 1000  -8.938755e-07 -2.689766e-08
#    rent bewteen 1000 and 2000  1.267860e-06  1.895702e-06
#    rent 2000 or more          -9.774919e-07 -1.532868e-07},
#   'transportationtype_residents': {'Rsquared': 0.58241838733078066,
#    'coefficients': transportation car            3.559612e-06
#    transportation public         2.842903e-07
#    tranportation motorcycle      1.298183e-05
#    Transportation Other means   -6.394600e-07
#    number of cars               -2.966048e-06
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car          8.785110e-07  6.240714e-06
#    transportation public       9.095638e-08  4.776242e-07
#    tranportation motorcycle   -4.467521e-05  7.063887e-05
#    Transportation Other means -1.173972e-06 -1.049485e-07
#    number of cars             -6.115882e-06  1.837867e-07},
#   'typeof_household_residents': {'Rsquared': 0.56005201329545418,
#    'coefficients': family households       1.147339e-06
#    nonfamily households   -5.350784e-07
#    dtype: float64,
#    'interval':                                  0             1
#    family households     9.574027e-07  1.337276e-06
#    nonfamily households -7.741989e-07 -2.959579e-07}},
#  'Boilers': {'age_residents': {'Rsquared': 0.50970130164054073,
#    'coefficients': Population under 18             5.376257e-09
#    population between 18 and 34    1.725850e-08
#    population between 35 to 64    -6.225017e-09
#    population 65 and over          9.742771e-10
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18          -2.607025e-09  1.335954e-08
#    population between 18 and 34  8.152394e-09  2.636461e-08
#    population between 35 to 64  -1.855812e-08  6.108091e-09
#    population 65 and over       -1.917928e-08  2.112784e-08},
#   'education_residents': {'Rsquared': 0.42921976762051028,
#    'coefficients': population education high school    1.406819e-08
#    population education bachelors      1.178383e-08
#    population education masters       -1.544937e-08
#    population education phd            5.049424e-08
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school  7.520732e-09  2.061565e-08
#    population education bachelors   -9.084761e-09  3.265242e-08
#    population education masters     -5.925840e-08  2.835965e-08
#    population education phd         -6.701369e-08  1.680022e-07},
#   'housing_values_residents': {'Rsquared': 0.23900372953231475,
#    'coefficients': house value for 20 to 100     1.083567e-07
#    house value for 100 to 500    1.340124e-08
#    house value 500 or more       1.797205e-08
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100   1.043302e-08  2.062804e-07
#    house value for 100 to 500 -2.216078e-09  2.901857e-08
#    house value 500 or more     5.489785e-09  3.045432e-08},
#   'income_residents': {'Rsquared': 0.52474584757623366,
#    'coefficients': household income form 10 to 40    4.643419e-08
#    household income form 40 to 75   -2.552201e-08
#    household income 75 and above     4.653903e-09
#    dtype: float64,
#    'interval':                                            0             1
#    household income form 10 to 40  2.594213e-08  6.692625e-08
#    household income form 40 to 75 -6.043423e-08  9.390221e-09
#    household income 75 and above  -3.124870e-09  1.243268e-08},
#   'ownorrent_residents': {'Rsquared': 0.53518332918114764,
#    'coefficients': owner  occupied units   -6.159363e-09
#    renter occupied units    1.630006e-08
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units -1.279223e-08  4.735055e-10
#    renter occupied units  1.321900e-08  1.938111e-08},
#   'race_residents': {'Rsquared': 0.55057743402058623,
#    'coefficients': Population white         3.115331e-09
#    population black         3.007675e-09
#    Population asian        -3.081981e-09
#    population hispanic      8.176311e-09
#    population other race    1.273939e-09
#    dtype: float64,
#    'interval':                                   0             1
#    Population white       1.514297e-09  4.716366e-09
#    population black       1.145122e-09  4.870228e-09
#    Population asian      -7.058902e-09  8.949390e-10
#    population hispanic    6.122387e-09  1.023023e-08
#    population other race -1.477853e-08  1.732641e-08},
#   'rent_residents': {'Rsquared': 0.54809367624516692,
#    'coefficients': rent bewteen 300 and 1000     2.261576e-08
#    rent bewteen 1000 and 2000    1.242908e-08
#    rent 2000 or more             3.626174e-09
#    dtype: float64,
#    'interval':                                        0             1
#    rent bewteen 300 and 1000   1.319739e-08  3.203412e-08
#    rent bewteen 1000 and 2000  5.577505e-09  1.928066e-08
#    rent 2000 or more          -5.260464e-09  1.251281e-08},
#   'transportationtype_residents': {'Rsquared': 0.47508174264852154,
#    'coefficients': transportation car           -1.620332e-08
#    transportation public         1.399769e-08
#    tranportation motorcycle     -1.942977e-06
#    Transportation Other means    7.541080e-09
#    number of cars                1.878301e-08
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -8.663631e-08  5.422967e-08
#    transportation public       8.890057e-09  1.910532e-08
#    tranportation motorcycle   -3.452358e-06 -4.335949e-07
#    Transportation Other means -6.262056e-09  2.134422e-08
#    number of cars             -6.425172e-08  1.018177e-07},
#   'typeof_household_residents': {'Rsquared': 0.46914716104536902,
#    'coefficients': family households       1.009493e-08
#    nonfamily households    8.808766e-09
#    dtype: float64,
#    'interval':                                  0             1
#    family households     5.209277e-09  1.498057e-08
#    nonfamily households  2.743378e-09  1.487415e-08}},
#  'Broken Muni Meter': {'age_residents': {'Rsquared': 0.33600074953690828,
#    'coefficients': Population under 18            -5.051331e-07
#    population between 18 and 34    4.406147e-07
#    population between 35 to 64    -1.589414e-07
#    population 65 and over          8.904314e-07
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18          -7.564055e-07 -2.538607e-07
#    population between 18 and 34  1.559984e-07  7.252309e-07
#    population between 35 to 64  -5.426720e-07  2.247893e-07
#    population 65 and over        2.687908e-07  1.512072e-06},
#   'education_residents': {'Rsquared': 0.40636401908873288,
#    'coefficients': population education high school   -1.645715e-07
#    population education bachelors      1.695722e-08
#    population education masters        1.647245e-06
#    population education phd           -2.697598e-06
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school -3.439393e-07  1.479628e-08
#    population education bachelors   -5.507794e-07  5.846939e-07
#    population education masters      4.595345e-07  2.834956e-06
#    population education phd         -5.902001e-06  5.068059e-07},
#   'housing_values_residents': {'Rsquared': 0.32429507389581236,
#    'coefficients': house value for 20 to 100     3.421197e-07
#    house value for 100 to 500   -2.778534e-07
#    house value 500 or more       1.246634e-06
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100  -2.146203e-06  2.830442e-06
#    house value for 100 to 500 -6.744494e-07  1.187426e-07
#    house value 500 or more     9.323024e-07  1.560965e-06},
#   'income_residents': {'Rsquared': 0.43143992337558579,
#    'coefficients': household income form 10 to 40    8.097548e-07
#    household income form 40 to 75   -1.864628e-06
#    household income 75 and above     9.848256e-07
#    dtype: float64,
#    'interval':                                            0             1
#    household income form 10 to 40  2.094520e-07  1.410058e-06
#    household income form 40 to 75 -2.881659e-06 -8.475967e-07
#    household income 75 and above   7.568033e-07  1.212848e-06},
#   'ownorrent_residents': {'Rsquared': 0.26539599900579935,
#    'coefficients': owner  occupied units    2.986188e-07
#    renter occupied units    1.605294e-07
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units  7.775787e-08  5.194797e-07
#    renter occupied units  5.617343e-08  2.648853e-07},
#   'race_residents': {'Rsquared': 0.30415318913209355,
#    'coefficients': Population white         1.639803e-07
#    population black        -2.517030e-09
#    Population asian         9.827168e-08
#    population hispanic     -1.733042e-08
#    population other race    1.188111e-07
#    dtype: float64,
#    'interval':                                   0             1
#    Population white       1.107700e-07  2.171905e-07
#    population black      -6.550039e-08  6.046634e-08
#    Population asian      -3.032268e-08  2.268660e-07
#    population hispanic   -8.469179e-08  5.003095e-08
#    population other race -4.178234e-07  6.554457e-07},
#   'rent_residents': {'Rsquared': 0.41983634609497422,
#    'coefficients': rent bewteen 300 and 1000    -2.770887e-08
#    rent bewteen 1000 and 2000    9.301773e-08
#    rent 2000 or more             1.251724e-06
#    dtype: float64,
#    'interval':                                        0             1
#    rent bewteen 300 and 1000  -3.182331e-07  2.628154e-07
#    rent bewteen 1000 and 2000 -1.144916e-07  3.005271e-07
#    rent 2000 or more           9.801852e-07  1.523263e-06},
#   'transportationtype_residents': {'Rsquared': 0.3939477677609291,
#    'coefficients': transportation car           -5.361425e-08
#    transportation public        -9.092305e-08
#    tranportation motorcycle      2.781101e-05
#    Transportation Other means    1.369074e-06
#    number of cars                1.293253e-07
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -2.063608e-06  1.956380e-06
#    transportation public      -2.363397e-07  5.449363e-08
#    tranportation motorcycle   -1.518359e-05  7.080561e-05
#    Transportation Other means  9.704537e-07  1.767695e-06
#    number of cars             -2.240678e-06  2.499328e-06},
#   'typeof_household_residents': {'Rsquared': 0.37439778678674906,
#    'coefficients': family households      -1.859463e-07
#    nonfamily households    6.854554e-07
#    dtype: float64,
#    'interval':                                  0             1
#    family households    -3.283506e-07 -4.354203e-08
#    nonfamily households  5.082162e-07  8.626946e-07}},
#  'Broken Parking Meter': {'age_residents': {'Rsquared': 0.44443227464067414,
#    'coefficients': Population under 18            -8.287626e-10
#    population between 18 and 34    1.869442e-09
#    population between 35 to 64    -1.157913e-09
#    population 65 and over          4.921547e-09
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18          -3.108804e-09  1.451279e-09
#    population between 18 and 34 -7.940285e-10  4.532912e-09
#    population between 35 to 64  -4.779583e-09  2.463756e-09
#    population 65 and over       -1.255046e-09  1.109814e-08},
#   'education_residents': {'Rsquared': 0.42554573442651689,
#    'coefficients': population education high school    1.361356e-09
#    population education bachelors      1.460206e-09
#    population education masters        7.588860e-10
#    population education phd            2.549586e-09
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school -8.442967e-10  3.567008e-09
#    population education bachelors   -3.600724e-09  6.521135e-09
#    population education masters     -9.470718e-09  1.098849e-08
#    population education phd         -2.562249e-08  3.072166e-08},
#   'housing_values_residents': {'Rsquared': 0.40921746188428854,
#    'coefficients': house value for 20 to 100     5.568883e-08
#    house value for 100 to 500    1.167999e-09
#    house value 500 or more       2.783392e-09
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100  -2.630145e-09  1.140078e-07
#    house value for 100 to 500 -4.781660e-09  7.117658e-09
#    house value 500 or more    -2.898307e-10  5.856616e-09},
#   'income_residents': {'Rsquared': 0.44009014694370796,
#    'coefficients': household income form 10 to 40    4.887226e-11
#    household income form 40 to 75    3.192652e-09
#    household income 75 and above     1.666681e-09
#    dtype: float64,
#    'interval':                                            0             1
#    household income form 10 to 40 -6.938410e-09  7.036155e-09
#    household income form 40 to 75 -8.103551e-09  1.448885e-08
#    household income 75 and above  -4.439349e-10  3.777296e-09},
#   'ownorrent_residents': {'Rsquared': 0.43503530349888964,
#    'coefficients': owner  occupied units    1.560261e-09
#    renter occupied units    1.438252e-09
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units -1.037518e-09  4.158040e-09
#    renter occupied units  2.434044e-10  2.633100e-09},
#   'race_residents': {'Rsquared': 0.4156588710781336,
#    'coefficients': Population white         6.281168e-10
#    population black         4.536131e-10
#    Population asian         6.945541e-10
#    population hispanic      8.331952e-11
#    population other race    4.438489e-09
#    dtype: float64,
#    'interval':                                   0             1
#    Population white       6.265645e-11  1.193577e-09
#    population black      -5.078106e-10  1.415037e-09
#    Population asian      -6.880750e-10  2.077183e-09
#    population hispanic   -8.185902e-10  9.852293e-10
#    population other race -1.056606e-08  1.944304e-08},
#   'rent_residents': {'Rsquared': 0.4474371197258119,
#    'coefficients': rent bewteen 300 and 1000    -5.535838e-10
#    rent bewteen 1000 and 2000    2.913162e-09
#    rent 2000 or more             3.119139e-09
#    dtype: float64,
#    'interval':                                        0             1
#    rent bewteen 300 and 1000  -4.015218e-09  2.908050e-09
#    rent bewteen 1000 and 2000  7.218403e-10  5.104484e-09
#    rent 2000 or more           7.387586e-10  5.499519e-09},
#   'transportationtype_residents': {'Rsquared': 0.46618261532238858,
#    'coefficients': transportation car            1.026306e-09
#    transportation public        -3.213933e-10
#    tranportation motorcycle      2.092849e-07
#    Transportation Other means    4.485891e-09
#    number of cars                2.185362e-09
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -1.936964e-08  2.142225e-08
#    transportation public      -1.868193e-09  1.225407e-09
#    tranportation motorcycle   -2.212487e-07  6.398184e-07
#    Transportation Other means  9.757755e-10  7.996007e-09
#    number of cars             -2.289972e-08  2.727044e-08},
#   'typeof_household_residents': {'Rsquared': 0.43764554774199127,
#    'coefficients': family households       1.091331e-09
#    nonfamily households    1.805466e-09
#    dtype: float64,
#    'interval':                                  0             1
#    family households    -5.725569e-10  2.755218e-09
#    nonfamily households  1.576182e-10  3.453314e-09}},
#  'Building/Use': {'age_residents': {'Rsquared': 0.44069211817382503,
#    'coefficients': Population under 18             5.573080e-08
#    population between 18 and 34   -2.344891e-07
#    population between 35 to 64     4.300530e-07
#    population 65 and over         -4.486445e-07
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18          -8.330575e-08  1.947673e-07
#    population between 18 and 34 -3.913552e-07 -7.762297e-08
#    population between 35 to 64   2.173059e-07  6.428001e-07
#    population 65 and over       -7.933301e-07 -1.039589e-07},
#   'education_residents': {'Rsquared': 0.47020535245787309,
#    'coefficients': population education high school    3.352073e-07
#    population education bachelors      1.223989e-07
#    population education masters       -1.149812e-07
#    population education phd           -5.892914e-07
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school  2.336797e-07  4.367349e-07
#    population education bachelors   -2.018103e-07  4.466081e-07
#    population education masters     -7.925350e-07  5.625726e-07
#    population education phd         -2.421612e-06  1.243029e-06},
#   'housing_values_residents': {'Rsquared': 0.46631326677507778,
#    'coefficients': house value for 20 to 100    -8.772267e-08
#    house value for 100 to 500    8.813513e-07
#    house value 500 or more       1.270559e-07
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100  -1.423638e-06  1.248193e-06
#    house value for 100 to 500  6.754164e-07  1.087286e-06
#    house value 500 or more    -4.073717e-08  2.948490e-07},
#   'income_residents': {'Rsquared': 0.39136314927151772,
#    'coefficients': household income form 10 to 40   -4.849993e-07
#    household income form 40 to 75    1.535227e-06
#    household income 75 and above    -1.813216e-07
#    dtype: float64,
#    'interval':                                            0             1
#    household income form 10 to 40 -8.592986e-07 -1.107000e-07
#    household income form 40 to 75  8.990274e-07  2.171426e-06
#    household income 75 and above  -3.244303e-07 -3.821294e-08},
#   'ownorrent_residents': {'Rsquared': 0.40419184105472972,
#    'coefficients': owner  occupied units    4.411040e-07
#    renter occupied units    6.051598e-09
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units  3.248102e-07  5.573979e-07
#    renter occupied units -4.982682e-08  6.193002e-08},
#   'race_residents': {'Rsquared': 0.51199249691668136,
#    'coefficients': Population white         6.901086e-09
#    population black         4.011388e-08
#    Population asian         1.261478e-07
#    population hispanic      2.657615e-08
#    population other race    7.573254e-07
#    dtype: float64,
#    'interval':                                   0             1
#    Population white      -1.991538e-08  3.371755e-08
#    population black       8.769236e-09  7.145853e-08
#    Population asian       6.082208e-08  1.914736e-07
#    population hispanic   -7.372461e-09  6.052476e-08
#    population other race  4.848003e-07  1.029851e-06},
#   'rent_residents': {'Rsquared': 0.29824534903784428,
#    'coefficients': rent bewteen 300 and 1000    -8.909085e-08
#    rent bewteen 1000 and 2000    4.301387e-07
#    rent 2000 or more            -1.177582e-07
#    dtype: float64,
#    'interval':                                        0             1
#    rent bewteen 300 and 1000  -2.798574e-07  1.016757e-07
#    rent bewteen 1000 and 2000  2.921089e-07  5.681686e-07
#    rent 2000 or more          -2.989710e-07  6.345459e-08},
#   'transportationtype_residents': {'Rsquared': 0.53468611420765177,
#    'coefficients': transportation car            1.005725e-06
#    transportation public        -1.037394e-08
#    tranportation motorcycle      8.998309e-06
#    Transportation Other means   -1.819524e-08
#    number of cars               -5.814680e-07
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -5.570301e-08  2.067154e-06
#    transportation public      -8.689865e-08  6.615077e-08
#    tranportation motorcycle   -1.382363e-05  3.182024e-05
#    Transportation Other means -2.297664e-07  1.933759e-07
#    number of cars             -1.828450e-06  6.655141e-07},
#   'typeof_household_residents': {'Rsquared': 0.46149472657975366,
#    'coefficients': family households       4.043107e-07
#    nonfamily households   -2.119022e-07
#    dtype: float64,
#    'interval':                                  0             1
#    family households     3.255248e-07  4.830967e-07
#    nonfamily households -3.110930e-07 -1.127115e-07}},
#  'Bus Stop Shelter Placement': {'age_residents': {'Rsquared': 0.48508480163632683,
#    'coefficients': Population under 18            -5.792165e-10
#    population between 18 and 34    9.947689e-10
#    population between 35 to 64     8.843543e-10
#    population 65 and over          1.298679e-09
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18          -2.506636e-09  1.348203e-09
#    population between 18 and 34 -1.499775e-09  3.489313e-09
#    population between 35 to 64  -2.177789e-09  3.946497e-09
#    population 65 and over       -3.503820e-09  6.101178e-09},
#   'education_residents': {'Rsquared': 0.50700556774790195,
#    'coefficients': population education high school    1.533674e-09
#    population education bachelors      4.279467e-10
#    population education masters        9.187929e-09
#    population education phd           -3.247474e-08
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school  6.487999e-11  3.002468e-09
#    population education bachelors   -4.189230e-09  5.045123e-09
#    population education masters     -8.388573e-10  1.921472e-08
#    population education phd         -6.275089e-08 -2.198597e-09},
#   'housing_values_residents': {'Rsquared': 0.44014863669617277,
#    'coefficients': house value for 20 to 100     1.398886e-08
#    house value for 100 to 500    4.613332e-09
#    house value 500 or more       4.095453e-09
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100  -3.290955e-09  3.126867e-08
#    house value for 100 to 500  1.593538e-09  7.633127e-09
#    house value 500 or more     1.728203e-09  6.462703e-09},
#   'income_residents': {'Rsquared': 0.48531857261794464,
#    'coefficients': household income form 10 to 40    1.720093e-09
#    household income form 40 to 75    2.940465e-09
#    household income 75 and above     1.402314e-09
#    dtype: float64,
#    'interval':                                            0             1
#    household income form 10 to 40 -3.822013e-09  7.262199e-09
#    household income form 40 to 75 -5.916191e-09  1.179712e-08
#    household income 75 and above  -3.959067e-10  3.200535e-09},
#   'ownorrent_residents': {'Rsquared': 0.49330542804118316,
#    'coefficients': owner  occupied units    2.601757e-09
#    renter occupied units    1.356058e-09
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units  9.861222e-10  4.217391e-09
#    renter occupied units  5.698777e-10  2.142238e-09},
#   'race_residents': {'Rsquared': 0.49395557362502451,
#    'coefficients': Population white         9.271332e-10
#    population black         6.309015e-10
#    Population asian        -4.763972e-11
#    population hispanic      8.331056e-10
#    population other race   -5.839582e-10
#    dtype: float64,
#    'interval':                                   0             1
#    Population white       5.440810e-10  1.310185e-09
#    population black       2.083886e-10  1.053414e-09
#    Population asian      -1.146534e-09  1.051254e-09
#    population hispanic    1.916315e-10  1.474580e-09
#    population other race -4.144865e-09  2.976949e-09},
#   'rent_residents': {'Rsquared': 0.44095713825814853,
#    'coefficients': rent bewteen 300 and 1000     2.178121e-09
#    rent bewteen 1000 and 2000    2.526111e-09
#    rent 2000 or more             2.084153e-09
#    dtype: float64,
#    'interval':                                        0             1
#    rent bewteen 300 and 1000  -2.281724e-10  4.584414e-09
#    rent bewteen 1000 and 2000  8.452843e-10  4.206939e-09
#    rent 2000 or more          -1.669376e-10  4.335244e-09},
#   'transportationtype_residents': {'Rsquared': 0.51739407034074936,
#    'coefficients': transportation car           -1.668453e-08
#    transportation public         7.237330e-10
#    tranportation motorcycle     -1.567472e-10
#    Transportation Other means    3.335188e-09
#    number of cars                2.344252e-08
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -3.717209e-08  3.803038e-09
#    transportation public      -4.713726e-10  1.918839e-09
#    tranportation motorcycle   -3.947149e-07  3.944014e-07
# ...
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units  2.357184e-08  5.850496e-08
#    renter occupied units -6.630768e-09  1.014266e-08},
#   'race_residents': {'Rsquared': 0.21657913821004526,
#    'coefficients': Population white         8.213351e-09
#    population black         9.076229e-09
#    Population asian        -3.357988e-09
#    population hispanic      1.680707e-09
#    population other race    9.448620e-09
#    dtype: float64,
#    'interval':                                   0             1
#    Population white       2.925716e-09  1.350099e-08
#    population black       4.134508e-09  1.401795e-08
#    Population asian      -1.457239e-08  7.856418e-09
#    population hispanic   -3.704855e-09  7.066268e-09
#    population other race -3.392314e-08  5.282038e-08},
#   'rent_residents': {},
#   'transportationtype_residents': {'Rsquared': 0.27475675865886995,
#    'coefficients': transportation car           -1.997594e-07
#    transportation public         3.852781e-09
#    tranportation motorcycle     -1.017817e-06
#    Transportation Other means    1.919404e-09
#    number of cars                2.850753e-07
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -3.733302e-07 -2.618858e-08
#    transportation public      -9.362472e-09  1.706803e-08
#    tranportation motorcycle   -4.768647e-06  2.733013e-06
#    Transportation Other means -4.142652e-08  4.526533e-08
#    number of cars              8.194927e-08  4.882013e-07},
#   'typeof_household_residents': {'Rsquared': 0.2084617332713341,
#    'coefficients': family households       3.282393e-08
#    nonfamily households   -1.748050e-08
#    dtype: float64,
#    'interval':                                  0             1
#    family households     1.856226e-08  4.708560e-08
#    nonfamily households -3.908526e-08  4.124259e-09}},
#  'Vending': {'age_residents': {},
#   'education_residents': {},
#   'housing_values_residents': {},
#   'income_residents': {},
#   'ownorrent_residents': {},
#   'race_residents': {},
#   'rent_residents': {},
#   'transportationtype_residents': {},
#   'typeof_household_residents': {}},
#  'Violation of Park Rules': {'age_residents': {},
#   'education_residents': {},
#   'housing_values_residents': {},
#   'income_residents': {},
#   'ownorrent_residents': {},
#   'race_residents': {},
#   'rent_residents': {},
#   'transportationtype_residents': {},
#   'typeof_household_residents': {}},
#  'WATER LEAK': {'age_residents': {'Rsquared': 0.56670301000158174,
#    'coefficients': Population under 18             2.753457e-07
#    population between 18 and 34    1.698506e-07
#    population between 35 to 64    -3.588600e-08
#    population 65 and over         -2.341044e-07
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18           1.554289e-07  3.952624e-07
#    population between 18 and 34  3.452305e-08  3.051782e-07
#    population between 35 to 64  -2.191008e-07  1.473288e-07
#    population 65 and over       -5.305075e-07  6.229878e-08},
#   'education_residents': {'Rsquared': 0.47941901812816157,
#    'coefficients': population education high school    3.799231e-07
#    population education bachelors     -1.879723e-08
#    population education masters       -1.139934e-07
#    population education phd            6.750406e-07
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school  2.813342e-07  4.785120e-07
#    population education bachelors   -3.332651e-07  2.956707e-07
#    population education masters     -7.711511e-07  5.431642e-07
#    population education phd         -1.104840e-06  2.454922e-06},
#   'housing_values_residents': {'Rsquared': 0.22062694454513876,
#    'coefficients': house value for 20 to 100     2.330650e-06
#    house value for 100 to 500    3.289808e-07
#    house value 500 or more       9.949020e-08
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100   7.479772e-07  3.913322e-06
#    house value for 100 to 500  8.500814e-08  5.729535e-07
#    house value 500 or more    -9.929577e-08  2.982762e-07},
#   'income_residents': {'Rsquared': 0.61522672749777496,
#    'coefficients': household income form 10 to 40    8.074171e-07
#    household income form 40 to 75   -1.108787e-07
#    household income 75 and above    -1.333688e-07
#    dtype: float64,
#    'interval':                                            0             1
#    household income form 10 to 40  5.157174e-07  1.099117e-06
#    household income form 40 to 75 -6.064375e-07  3.846800e-07
#    household income 75 and above  -2.448021e-07 -2.193541e-08},
#   'ownorrent_residents': {'Rsquared': 0.53351145781096432,
#    'coefficients': owner  occupied units   -1.464848e-07
#    renter occupied units    2.904179e-07
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units -2.473115e-07 -4.565811e-08
#    renter occupied units  2.419978e-07  3.388380e-07},
#   'race_residents': {'Rsquared': 0.66771595083553736,
#    'coefficients': Population white         2.140186e-08
#    population black         1.071169e-07
#    Population asian        -3.940187e-08
#    population hispanic      1.425709e-07
#    population other race   -1.436068e-07
#    dtype: float64,
#    'interval':                                   0             1
#    Population white      -2.906142e-10  4.309433e-08
#    population black       8.176772e-08  1.324662e-07
#    Population asian      -9.224719e-08  1.344345e-08
#    population hispanic    1.151080e-07  1.700338e-07
#    population other race -3.640640e-07  7.685035e-08},
#   'rent_residents': {'Rsquared': 0.63561701806462212,
#    'coefficients': rent bewteen 300 and 1000     4.084394e-07
#    rent bewteen 1000 and 2000    3.053114e-07
#    rent 2000 or more            -2.502831e-07
#    dtype: float64,
#    'interval':                                        0             1
#    rent bewteen 300 and 1000   2.738008e-07  5.430779e-07
#    rent bewteen 1000 and 2000  2.078092e-07  4.028135e-07
#    rent 2000 or more          -3.782793e-07 -1.222868e-07},
#   'transportationtype_residents': {'Rsquared': 0.48616479489663944,
#    'coefficients': transportation car           -2.829849e-07
#    transportation public         3.150638e-07
#    tranportation motorcycle     -3.414888e-05
#    Transportation Other means   -2.405604e-07
#    number of cars                3.169857e-07
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -1.376233e-06  8.102628e-07
#    transportation public       2.362299e-07  3.938977e-07
#    tranportation motorcycle   -5.765910e-05 -1.063866e-05
#    Transportation Other means -4.585124e-07 -2.260840e-08
#    number of cars             -9.673932e-07  1.601365e-06},
#   'typeof_household_residents': {'Rsquared': 0.47828412444427426,
#    'coefficients': family households       2.908911e-07
#    nonfamily households   -1.675895e-08
#    dtype: float64,
#    'interval':                                  0             1
#    family households     2.148676e-07  3.669147e-07
#    nonfamily households -1.124689e-07  7.895104e-08}},
#  'Water Conservation': {'age_residents': {'Rsquared': 0.23158834959782049,
#    'coefficients': Population under 18             1.626156e-08
#    population between 18 and 34   -4.347316e-08
#    population between 35 to 64     5.641467e-08
#    population 65 and over         -2.733179e-08
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18          -2.211265e-08  5.463576e-08
#    population between 18 and 34 -8.676790e-08 -1.784165e-10
#    population between 35 to 64  -2.302836e-09  1.151322e-07
#    population 65 and over       -1.224705e-07  6.780693e-08},
#   'education_residents': {'Rsquared': 0.24217793781597952,
#    'coefficients': population education high school    5.291065e-08
#    population education bachelors     -1.831087e-08
#    population education masters        1.094703e-07
#    population education phd           -3.579749e-07
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school  2.431362e-08  8.150769e-08
#    population education bachelors   -1.096138e-07  7.299204e-08
#    population education masters     -8.134174e-08  3.002824e-07
#    population education phd         -8.739989e-07  1.580490e-07},
#   'housing_values_residents': {'Rsquared': 0.30915942645298422,
#    'coefficients': house value for 20 to 100    -2.409556e-09
#    house value for 100 to 500    1.731712e-07
#    house value 500 or more       1.751422e-08
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100  -3.603964e-07  3.555773e-07
#    house value for 100 to 500  1.179985e-07  2.283440e-07
#    house value 500 or more    -2.743786e-08  6.246631e-08},
#   'income_residents': {},
#   'ownorrent_residents': {'Rsquared': 0.26301062329452796,
#    'coefficients': owner  occupied units    9.269602e-08
#    renter occupied units   -4.863879e-09
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units  6.223673e-08  1.231553e-07
#    renter occupied units -1.950191e-08  9.774156e-09},
#   'race_residents': {'Rsquared': 0.20961790923562384,
#    'coefficients': Population white         1.223529e-08
#    population black         1.183169e-08
#    Population asian         6.276576e-09
#    population hispanic      7.330632e-09
#    population other race    7.056138e-09
#    dtype: float64,
#    'interval':                                   0             1
#    Population white       4.199337e-09  2.027125e-08
#    population black       2.438258e-09  2.122513e-08
#    Population asian      -1.329927e-08  2.585242e-08
#    population hispanic   -2.843631e-09  1.750489e-08
#    population other race -7.461077e-08  8.872304e-08},
#   'rent_residents': {},
#   'transportationtype_residents': {'Rsquared': 0.35005902368050679,
#    'coefficients': transportation car           -1.899648e-07
#    transportation public        -1.146093e-08
#    tranportation motorcycle      1.179034e-06
#    Transportation Other means    3.031119e-08
#    number of cars                3.547911e-07
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -4.853714e-07  1.054418e-07
#    transportation public      -3.275690e-08  9.835050e-09
#    tranportation motorcycle   -5.172317e-06  7.530385e-06
#    Transportation Other means -2.857068e-08  8.919306e-08
#    number of cars              7.743438e-09  7.018387e-07},
#   'typeof_household_residents': {'Rsquared': 0.23952762635294733,
#    'coefficients': family households       6.409783e-08
#    nonfamily households   -2.737307e-08
#    dtype: float64,
#    'interval':                                  0             1
#    family households     4.205203e-08  8.614363e-08
#    nonfamily households -5.512913e-08  3.829870e-10}},
#  'Water Quality': {'age_residents': {'Rsquared': 0.52120532729814029,
#    'coefficients': Population under 18            -1.286070e-09
#    population between 18 and 34    3.044720e-09
#    population between 35 to 64    -7.536002e-10
#    population 65 and over          1.869716e-08
#    dtype: float64,
#    'interval':                                          0             1
#    Population under 18          -6.583423e-09  4.011283e-09
#    population between 18 and 34 -2.936749e-09  9.026189e-09
#    population between 35 to 64  -8.912069e-09  7.404868e-09
#    population 65 and over        5.386190e-09  3.200813e-08},
#   'education_residents': {'Rsquared': 0.53118764008548069,
#    'coefficients': population education high school    6.410306e-09
#    population education bachelors      5.309949e-09
#    population education masters        2.182489e-08
#    population education phd           -7.053622e-08
#    dtype: float64,
#    'interval':                                              0             1
#    population education high school  2.465826e-09  1.035479e-08
#    population education bachelors   -7.304920e-09  1.792482e-08
#    population education masters     -4.538573e-09  4.818835e-08
#    population education phd         -1.415366e-07  4.641526e-10},
#   'housing_values_residents': {'Rsquared': 0.55695800910363924,
#    'coefficients': house value for 20 to 100     1.353027e-08
#    house value for 100 to 500    2.527391e-08
#    house value 500 or more       1.867173e-08
#    dtype: float64,
#    'interval':                                        0             1
#    house value for 20 to 100  -3.688852e-08  6.394905e-08
#    house value for 100 to 500  1.753555e-08  3.301228e-08
#    house value 500 or more     1.235384e-08  2.498962e-08},
#   'income_residents': {'Rsquared': 0.51264032031415296,
#    'coefficients': household income form 10 to 40   -2.491290e-10
#    household income form 40 to 75    1.695006e-08
#    household income 75 and above     8.096233e-09
#    dtype: float64,
#    'interval':                                            0             1
#    household income form 10 to 40 -1.406431e-08  1.356605e-08
#    household income form 40 to 75 -6.528698e-09  4.042883e-08
#    household income 75 and above   2.823221e-09  1.336925e-08},
#   'ownorrent_residents': {'Rsquared': 0.568332537090116,
#    'coefficients': owner  occupied units    1.766181e-08
#    renter occupied units    2.426905e-09
#    dtype: float64,
#    'interval':                                   0             1
#    owner  occupied units  1.357526e-08  2.174835e-08
#    renter occupied units  4.625652e-10  4.391246e-09},
#   'race_residents': {'Rsquared': 0.54151686352134232,
#    'coefficients': Population white         4.778185e-09
#    population black         2.038660e-09
#    Population asian         1.416749e-09
#    population hispanic      1.306163e-09
#    population other race    5.968233e-10
#    dtype: float64,
#    'interval':                                   0             1
#    Population white       3.705057e-09  5.851312e-09
#    population black       7.818464e-10  3.295475e-09
#    Population asian      -1.219248e-09  4.052745e-09
#    population hispanic   -5.141882e-11  2.663745e-09
#    population other race -1.028152e-08  1.147517e-08},
#   'rent_residents': {'Rsquared': 0.40189701351445273,
#    'coefficients': rent bewteen 300 and 1000     2.727085e-09
#    rent bewteen 1000 and 2000    1.225773e-08
#    rent 2000 or more             9.451902e-09
#    dtype: float64,
#    'interval':                                        0             1
#    rent bewteen 300 and 1000  -4.596429e-09  1.005060e-08
#    rent bewteen 1000 and 2000  6.990590e-09  1.752487e-08
#    rent 2000 or more           2.568433e-09  1.633537e-08},
#   'transportationtype_residents': {'Rsquared': 0.63811246953720735,
#    'coefficients': transportation car           -6.095920e-08
#    transportation public        -1.055664e-09
#    tranportation motorcycle      5.383300e-07
#    Transportation Other means    1.650879e-08
#    number of cars                9.499672e-08
#    dtype: float64,
#    'interval':                                        0             1
#    transportation car         -9.976632e-08 -2.215208e-08
#    transportation public      -3.844169e-09  1.732841e-09
#    tranportation motorcycle   -2.913831e-07  1.368043e-06
#    Transportation Other means  8.815523e-09  2.420206e-08
#    number of cars              4.943971e-08  1.405537e-07},
#   'typeof_household_residents': {'Rsquared': 0.50666744446774681,
#    'coefficients': family households       9.018667e-09
#    nonfamily households    4.167851e-09
#    dtype: float64,
#    'interval':                                  0             1
#    family households     5.907291e-09  1.213004e-08
#    nonfamily households  2.528900e-10  8.082811e-09}},
#  'Water System': {'age_residents': {},
#   'education_residents': {},
#   'housing_values_residents': {},
#   'income_residents': {},
#   'ownorrent_residents': {},
#   'race_residents': {},
#   'rent_residents': {},
#   'transportationtype_residents': {},
#   'typeof_household_residents': {}}}

# %%
#coefficients table
coefficient_table=pd.DataFrame(ols_coefficients_filtered['Noise - Commercial']['age_residents']['coefficients'],columns={'coefficient'})
#interval table
conf_interval_table=ols_coefficients_filtered['Noise - Commercial']['age_residents']['interval']
conf_interval_table.columns=['min','max']
#filter for those variables with coefficients within the interval
for eem in coefficient_table.index:
    coeff= coefficient_table.loc[eem,'coefficient']
    min_c= conf_interval_table.loc[eem,'min']
    max_c= conf_interval_table.loc[eem,'max']
    if (coeff<min_c or coeff>max_c):
        coefficient_table.drop(eem,inplace=True)  
coefficient_table
# Out:
#                                coefficient
# Population under 18          -4.937346e-07
# population between 18 and 34  9.214939e-07
# population between 35 to 64  -1.589607e-07
# population 65 and over       -6.199498e-08

# %%
#NOW FOR ALL THE TYPES OF COMPLAINS WE OBTAIN THE TABLE:
OLS_results_final={}
for typeof in ols_coefficients_filtered.keys():
    OLS_results_final[typeof]={}
    for subgroup in ols_coefficients_filtered[typeof].keys():
        if len(ols_coefficients_filtered[typeof][subgroup])!=0:
            OLS_results_final[typeof][subgroup]={}
            OLS_results_final[typeof][subgroup]['Rsquared']=ols_coefficients_filtered[typeof][subgroup]['Rsquared']
            coefficient_table=pd.DataFrame(ols_coefficients_filtered[typeof][subgroup]['coefficients'],columns={'coefficient'})
            conf_interval_table=ols_coefficients_filtered[typeof][subgroup]['interval']
            conf_interval_table.columns=['min','max']
            for eem in coefficient_table.index:
                coeff= coefficient_table.loc[eem,'coefficient']
                min_c= conf_interval_table.loc[eem,'min']
                max_c= conf_interval_table.loc[eem,'max']
                if (coeff<min_c or coeff>max_c):
                    coefficient_table.drop(eem,inplace=True)  
            OLS_results_final[typeof][subgroup]['coefficients']=coefficient_table

# %%
#NOW FOR ALL THE TYPES OF COMPLAINS THE SAME TABLE WITHOUT THE R2 VALUES:
OLS_results_final={}
for typeof in ols_coefficients_filtered.keys():
    OLS_results_final[typeof]={}
    for subgroup in ols_coefficients_filtered[typeof].keys():
        if len(ols_coefficients_filtered[typeof][subgroup])!=0:
            OLS_results_final[typeof][subgroup]={}
            coefficient_table=pd.DataFrame(ols_coefficients_filtered[typeof][subgroup]['coefficients'],columns={'coefficient'})
            conf_interval_table=ols_coefficients_filtered[typeof][subgroup]['interval']
            conf_interval_table.columns=['min','max']
            for eem in coefficient_table.index:
                coeff= coefficient_table.loc[eem,'coefficient']
                min_c= conf_interval_table.loc[eem,'min']
                max_c= conf_interval_table.loc[eem,'max']
                if (coeff<min_c or coeff>max_c):
                    coefficient_table.drop(eem,inplace=True)  
            OLS_results_final[typeof][subgroup]['coefficients']=coefficient_table

# %%
#DUMPING THE DICTIONARY INTO A FRAME
a = pd.concat(map(pd.DataFrame, OLS_results_final.itervalues()), keys=OLS_results_final.keys()).stack().unstack(1).unstack(1)
a.columns = a.columns.droplevel(0)

# %%
#CREATING SEPARATE FRAMES FOR EACH GROUP OF DEMOGRAPHIC FEATURES 
dicframe = {}
for data_group in variable_groups_residents:
    c = pd.DataFrame(np.nan, index = eval(data_group), columns = [u'coefficient'])
    dicframe[data_group] = pd.DataFrame()
    for i in range (0, 84):
        d =  a[data_group][i]
        if d is None:
            dicframe[data_group] = pd.concat([dicframe[data_group] , c], axis=1, ignore_index=True)
        else:    
            dicframe[data_group] = pd.concat([dicframe[data_group] , d], axis=1, ignore_index=True)
    dicframe[data_group] = dicframe[data_group].T

# %%
#CREATING A COEFFICIENT FRAME
coefficients = pd.DataFrame()
for data_group in variable_groups_residents:
    coefficients = pd.concat([coefficients, dicframe[data_group]], axis=1)

# %%
#sETTING THE FRAME'S INDEX AS THE TYPES OF COMPLAINTS
coefficients = coefficients.set_index(a.index)

# %%
#STORING IT IN A CSV FOR VISUALIZATION
coefficients.to_csv('OLS_residents_coefficients.csv')

# %%
#FIRST, I WILL RUN OLS OVER EVERY TYPE OF COMPLAIN (FOR WORKERS)
ols_coefficients_dict={}
for typeof in types_of_calls:
    ols_coefficients_dict[typeof]={}
    A2=np.append(np.append(workers_features ,typeof),'Neighborhood')   #selection of columns
    myframe1=callsbytype_attributes_workers[A2].dropna() 
    if len(myframe1)>50:
        for data_group in variable_groups_workers:
            ols_coefficients_dict[typeof][data_group]={}
            #ols_coefficients_dict[typeof]['coefficients']={}
            #ols_coefficients_dict[typeof]['interval']={}
            features=eval(data_group)           
            A2=np.append(np.append(features ,typeof),'Neighborhood')   #selection of columns
            myframe1=callsbytype_attributes[A2].dropna() 
            X=myframe1[features]
            Y=myframe1[typeof]
            ordinary_LS=sm.OLS(Y, X).fit()
            ols_coefficients_dict[typeof][data_group]['coefficients']=ordinary_LS.params
            ols_coefficients_dict[typeof][data_group]['interval']=ordinary_LS.conf_int()
            ols_coefficients_dict[typeof][data_group]['Rsquared']=ordinary_LS.rsquared

# %%
len(ols_coefficients_dict)
# Out:
# 178

# %%
#NOW, RUN OLS OVER EVERY TYPE OF COMPLAIN WITH AN R2 HIGHER THAN 0.2 TO SUBSET THE TYPES OF 
#COMPLAINTS WE'RE USING
ols_coefficients_dict={}
for typeof in types_of_calls:
    ols_coefficients_dict[typeof]={}
    A2=np.append(np.append(workers_features,typeof),'Neighborhood')   #selection of columns
    myframe1=callsbytype_attributes_workers[A2].dropna() 
    if len(myframe1)>50:
        for data_group in variable_groups_workers:
            ols_coefficients_dict[typeof][data_group]={}
            #ols_coefficients_dict[typeof]['coefficients']={}
            #ols_coefficients_dict[typeof]['interval']={}
            features=eval(data_group)           
            A2=np.append(np.append(features ,typeof),'Neighborhood')   #selection of columns
            myframe1=callsbytype_attributes[A2].dropna() 
            X=myframe1[features]
            Y=myframe1[typeof]
            ordinary_LS=sm.OLS(Y, X).fit()
            rsq=ordinary_LS.rsquared
            if rsq>=0.2:
                ols_coefficients_dict[typeof][data_group]['coefficients']=ordinary_LS.params
                ols_coefficients_dict[typeof][data_group]['interval']=ordinary_LS.conf_int()
                ols_coefficients_dict[typeof][data_group]['Rsquared']=rsq
ols_coefficients_filtered={}
for typeof in ols_coefficients_dict.keys():
    if len(ols_coefficients_dict[typeof])>0:
        ols_coefficients_filtered[typeof]=ols_coefficients_dict[typeof]

# %%
len(ols_coefficients_filtered)
# Out:
# 133

# %%
#NOW FOR ALL THE TYPES OF COMPLAINS THE SAME TABLE WITHOUT THE R2 VALUES:
OLS_results_final={}
for typeof in ols_coefficients_filtered.keys():
    OLS_results_final[typeof]={}
    for subgroup in ols_coefficients_filtered[typeof].keys():
        if len(ols_coefficients_filtered[typeof][subgroup])!=0:
            OLS_results_final[typeof][subgroup]={}
            coefficient_table=pd.DataFrame(ols_coefficients_filtered[typeof][subgroup]['coefficients'],columns={'coefficient'})
            conf_interval_table=ols_coefficients_filtered[typeof][subgroup]['interval']
            conf_interval_table.columns=['min','max']
            for eem in coefficient_table.index:
                coeff= coefficient_table.loc[eem,'coefficient']
                min_c= conf_interval_table.loc[eem,'min']
                max_c= conf_interval_table.loc[eem,'max']
                if (coeff<min_c or coeff>max_c):
                    coefficient_table.drop(eem,inplace=True)  
            OLS_results_final[typeof][subgroup]['coefficients']=coefficient_table

# %%
ols_coefficients_filtered
# Out:
# {'APPLIANCE': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {'Rsquared': 0.2310224255007447,
#    'coefficients': house value for 20 to 100_n     1.518013e-06
#    house value for 100 to 500_n   -8.266890e-08
#    house value 500 or more_n      -1.080475e-07
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n   9.266440e-07  2.109382e-06
#    house value for 100 to 500_n -1.640612e-07 -1.276626e-09
#    house value 500 or more_n    -1.459624e-07 -7.013271e-08},
#   'income_workers': {'Rsquared': 0.21029869264168022,
#    'coefficients': household income form 10 to 40_n    5.030557e-07
#    household income form 40 to 75_n   -6.041455e-07
#    household income 75 and above_n     5.395145e-09
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n  2.529882e-07  7.531233e-07
#    household income form 40 to 75_n -9.810085e-07 -2.272824e-07
#    household income 75 and above_n  -3.734371e-08  4.813400e-08},
#   'ownorrent_workers': {},
#   'race_workers': {'Rsquared': 0.26880215260283569,
#    'coefficients': Population white_n      -4.876816e-08
#    population black_n       2.665694e-08
#    Population asian_n      -6.104335e-08
#    population hispanic_n    3.115888e-07
#    population other _n     -1.788544e-06
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -1.024910e-07  4.954677e-09
#    population black_n    -5.031649e-08  1.036304e-07
#    Population asian_n    -2.680923e-07  1.460056e-07
#    population hispanic_n  2.025798e-07  4.205979e-07
#    population other _n   -3.435377e-06 -1.417118e-07},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Air Quality': {'age_workers': {'Rsquared': 0.37029756333046582,
#    'coefficients': population between 18 and 34_n   -8.404341e-08
#    population between 35 to 64_n     3.227522e-07
#    population 65 and over_n         -7.522924e-07
#    dtype: float64,
#    'interval':                                          min           max
#    population between 18 and 34_n -2.908645e-07  1.227776e-07
#    population between 35 to 64_n  -1.471186e-08  6.602162e-07
#    population 65 and over_n       -1.531208e-06  2.662362e-08},
#   'education_workers': {'Rsquared': 0.40933847087172115,
#    'coefficients': population education high school_n    8.887003e-08
#    population education bachelors_n      8.854289e-07
#    population education masters_n       -2.430066e-06
#    population education phd_n            4.497571e-06
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n -2.544512e-08  2.031852e-07
#    population education bachelors_n    4.172735e-08  1.729130e-06
#    population education masters_n     -4.233058e-06 -6.270738e-07
#    population education phd_n          1.180810e-06  7.814332e-06},
#   'housing_values_workers': {'Rsquared': 0.37460758220353418,
#    'coefficients': house value for 20 to 100_n     3.401547e-07
#    house value for 100 to 500_n    5.004993e-09
#    house value 500 or more_n      -2.786901e-08
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n  -2.059617e-07  8.862712e-07
#    house value for 100 to 500_n -7.015030e-08  8.016029e-08
#    house value 500 or more_n    -6.288685e-08  7.148821e-09},
#   'income_workers': {'Rsquared': 0.39842509144972882,
#    'coefficients': household income form 10 to 40_n   -2.114100e-08
#    household income form 40 to 75_n    1.419210e-07
#    household income 75 and above_n    -4.349857e-08
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n -2.446402e-07  2.023582e-07
#    household income form 40 to 75_n -1.948888e-07  4.787309e-07
#    household income 75 and above_n  -8.169243e-08 -5.304700e-09},
#   'ownorrent_workers': {'Rsquared': 0.36691809420333366,
#    'coefficients': owner  occupied units_n   -3.881168e-08
#    renter occupied units_n    4.217285e-08
#    dtype: float64,
#    'interval':                                   min           max
#    owner  occupied units_n -1.000540e-07  2.243061e-08
#    renter occupied units_n  2.624641e-09  8.172105e-08},
#   'race_workers': {'Rsquared': 0.39872882058642112,
#    'coefficients': Population white_n      -3.522811e-08
#    population black_n       2.482957e-08
#    Population asian_n       8.612177e-08
#    population hispanic_n    1.032967e-07
#    population other _n     -5.367475e-07
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -8.510494e-08  1.464871e-08
#    population black_n    -4.665118e-08  9.631032e-08
#    Population asian_n    -1.061557e-07  2.783992e-07
#    population hispanic_n  2.059955e-09  2.045335e-07
#    population other _n   -2.066184e-06  9.926890e-07},
#   'rent_workers': {'Rsquared': 0.3890955705136917,
#    'coefficients': rent bewteen 300 and 1000_n     4.496949e-08
#    rent bewteen 1000 and 2000_n    1.709006e-08
#    rent 2000 or more_n            -5.342710e-08
#    dtype: float64,
#    'interval':                                        min           max
#    rent bewteen 300 and 1000_n  -1.184362e-07  2.083752e-07
#    rent bewteen 1000 and 2000_n -7.375154e-08  1.079317e-07
#    rent 2000 or more_n          -9.690348e-08 -9.950721e-09},
#   'transportationtype_workers': {'Rsquared': 0.39709372465652448,
#    'coefficients': transportation car_n           -1.793224e-07
#    transportation public_n         4.629639e-07
#    tranportation motorcycle_n     -2.161737e-06
#    Transportation Other means_n   -3.674787e-07
#    dtype: float64,
#    'interval':                                        min           max
#    transportation car_n         -3.447011e-07 -1.394375e-08
#    transportation public_n       1.401613e-07  7.857664e-07
#    tranportation motorcycle_n   -1.077923e-05  6.455761e-06
#    Transportation Other means_n -6.164013e-07 -1.185560e-07},
#   'typeof_household_workers': {'Rsquared': 0.37476954580493016,
#    'coefficients': family households_n       4.333393e-08
#    nonfamily households_n   -4.064876e-08
#    dtype: float64,
#    'interval':                                  min           max
#    family households_n     1.363229e-08  7.303556e-08
#    nonfamily households_n -8.417012e-08  2.872597e-09}},
#  'Animal Abuse': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Animal in a Park': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Asbestos': {'age_workers': {'Rsquared': 0.39657168176805235,
#    'coefficients': population between 18 and 34_n   -1.524074e-08
#    population between 35 to 64_n     9.589718e-08
#    population 65 and over_n         -2.474835e-07
#    dtype: float64,
#    'interval':                                          min           max
#    population between 18 and 34_n -6.405130e-08  3.356982e-08
#    population between 35 to 64_n   1.622189e-08  1.755725e-07
#    population 65 and over_n       -4.312579e-07 -6.370902e-08},
#   'education_workers': {'Rsquared': 0.43835732049757137,
#    'coefficients': population education high school_n    2.101514e-08
#    population education bachelors_n      2.602432e-07
#    population education masters_n       -7.127458e-07
#    population education phd_n            1.340954e-06
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n -5.830120e-09  4.786039e-08
#    population education bachelors_n    6.231531e-08  4.581710e-07
#    population education masters_n     -1.135651e-06 -2.898405e-07
#    population education phd_n          5.631440e-07  2.118765e-06},
#   'housing_values_workers': {'Rsquared': 0.41311966681136281,
#    'coefficients': house value for 20 to 100_n     1.766467e-07
#    house value for 100 to 500_n   -8.147864e-09
#    house value 500 or more_n      -9.855514e-09
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n   4.588885e-08  3.074045e-07
#    house value for 100 to 500_n -2.592163e-08  9.625901e-09
#    house value 500 or more_n    -1.810726e-08 -1.603770e-09},
#   'income_workers': {'Rsquared': 0.43073188660719719,
#    'coefficients': household income form 10 to 40_n    4.601537e-08
#    household income form 40 to 75_n   -4.064468e-08
#    household income 75 and above_n    -3.983485e-09
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n -6.618423e-09  9.864917e-08
#    household income form 40 to 75_n -1.199190e-07  3.862966e-08
#    household income 75 and above_n  -1.295032e-08  4.983351e-09},
#   'ownorrent_workers': {'Rsquared': 0.4053117452441487,
#    'coefficients': owner  occupied units_n   -2.032655e-08
#    renter occupied units_n    1.722103e-08
#    dtype: float64,
#    'interval':                                   min           max
#    owner  occupied units_n -3.464828e-08 -6.004823e-09
#    renter occupied units_n  7.972761e-09  2.646929e-08},
#   'race_workers': {'Rsquared': 0.45894204496983915,
#    'coefficients': Population white_n      -1.326154e-08
#    population black_n      -5.758363e-09
#    Population asian_n       1.596774e-08
#    population hispanic_n    4.912374e-08
#    population other _n     -1.670322e-07
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -2.471564e-08 -1.807442e-09
#    population black_n    -2.207093e-08  1.055420e-08
#    Population asian_n    -2.796555e-08  5.990102e-08
#    population hispanic_n  2.577538e-08  7.247211e-08
#    population other _n   -5.192594e-07  1.851950e-07},
#   'rent_workers': {'Rsquared': 0.40717486708549211,
#    'coefficients': rent bewteen 300 and 1000_n     2.096357e-08
#    rent bewteen 1000 and 2000_n   -1.392992e-09
#    rent 2000 or more_n            -1.226177e-08
#    dtype: float64,
#    'interval':                                        min           max
#    rent bewteen 300 and 1000_n  -1.802362e-08  5.995077e-08
#    rent bewteen 1000 and 2000_n -2.305555e-08  2.026956e-08
#    rent 2000 or more_n          -2.257849e-08 -1.945047e-09},
#   'transportationtype_workers': {'Rsquared': 0.43231615455138939,
#    'coefficients': transportation car_n           -7.264804e-08
#    transportation public_n         1.671370e-07
#    tranportation motorcycle_n     -2.078680e-06
#    Transportation Other means_n   -7.014964e-08
#    dtype: float64,
#    'interval':                                        min           max
#    transportation car_n         -1.113274e-07 -3.396867e-08
#    transportation public_n       9.163176e-08  2.426423e-07
#    tranportation motorcycle_n   -4.095151e-06 -6.220910e-08
#    Transportation Other means_n -1.282381e-07 -1.206118e-08},
#   'typeof_household_workers': {'Rsquared': 0.38640273155496074,
#    'coefficients': family households_n       9.681303e-09
#    nonfamily households_n   -8.706772e-09
#    dtype: float64,
#    'interval':                                  min           max
#    family households_n     2.588464e-09  1.677414e-08
#    nonfamily households_n -1.909849e-08  1.684946e-09}},
#  'BEST/Site Safety': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Beach/Pool/Sauna Complaint': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Bike/Roller/Skate Chronic': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Blocked Driveway': {'age_workers': {},
#   'education_workers': {'Rsquared': 0.22135264927051335,
#    'coefficients': population education high school_n    7.701727e-07
#    population education bachelors_n      1.091856e-05
#    population education masters_n       -2.794234e-05
#    population education phd_n            3.940738e-05
#    dtype: float64,
#    'interval':                                              min       max
#    population education high school_n -1.874613e-07  0.000002
#    population education bachelors_n    3.850590e-06  0.000018
#    population education masters_n     -4.304685e-05 -0.000013
#    population education phd_n          1.162049e-05  0.000067},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {'Rsquared': 0.25575291321795124,
#    'coefficients': rent bewteen 300 and 1000_n    -0.000003
#    rent bewteen 1000 and 2000_n    0.000002
#    rent 2000 or more_n            -0.000001
#    dtype: float64,
#    'interval':                                    min           max
#    rent bewteen 300 and 1000_n  -0.000004 -1.597639e-06
#    rent bewteen 1000 and 2000_n  0.000001  2.789912e-06
#    rent 2000 or more_n          -0.000002 -8.802539e-07},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Boilers': {'age_workers': {},
#   'education_workers': {'Rsquared': 0.25447304264307757,
#    'coefficients': population education high school_n    2.717429e-08
#    population education bachelors_n      2.009131e-07
#    population education masters_n       -6.372354e-07
#    population education phd_n            1.447235e-06
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n  5.663502e-09  4.868507e-08
#    population education bachelors_n    4.171769e-08  3.601085e-07
#    population education masters_n     -9.775756e-07 -2.968952e-07
#    population education phd_n          8.227115e-07  2.071759e-06},
#   'housing_values_workers': {'Rsquared': 0.30902547444395156,
#    'coefficients': house value for 20 to 100_n     2.896976e-07
#    house value for 100 to 500_n   -2.100994e-08
#    house value 500 or more_n      -1.513537e-08
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n   1.919488e-07  3.874464e-07
#    house value for 100 to 500_n -3.454034e-08 -7.479549e-09
#    house value 500 or more_n    -2.131051e-08 -8.960231e-09},
#   'income_workers': {'Rsquared': 0.26289119716957954,
#    'coefficients': household income form 10 to 40_n    8.041726e-08
#    household income form 40 to 75_n   -9.681723e-08
#    household income 75 and above_n     1.375802e-09
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n  3.857399e-08  1.222605e-07
#    household income form 40 to 75_n -1.599104e-07 -3.372407e-08
#    household income 75 and above_n  -5.767603e-09  8.519206e-09},
#   'ownorrent_workers': {},
#   'race_workers': {'Rsquared': 0.32984644970476762,
#    'coefficients': Population white_n      -8.453588e-09
#    population black_n      -2.235838e-09
#    Population asian_n      -4.166617e-09
#    population hispanic_n    5.604041e-08
#    population other _n     -3.002521e-07
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -1.738757e-08  4.803974e-10
#    population black_n    -1.487202e-08  1.040034e-08
#    Population asian_n    -3.836638e-08  3.003315e-08
#    population hispanic_n  3.803191e-08  7.404890e-08
#    population other _n   -5.729658e-07 -2.753837e-08},
#   'rent_workers': {'Rsquared': 0.21023403462643786,
#    'coefficients': rent bewteen 300 and 1000_n     4.680959e-08
#    rent bewteen 1000 and 2000_n   -1.770745e-08
#    rent 2000 or more_n            -1.208565e-08
#    dtype: float64,
#    'interval':                                        min           max
#    rent bewteen 300 and 1000_n   1.515427e-08  7.846490e-08
#    rent bewteen 1000 and 2000_n -3.533204e-08 -8.285644e-11
#    rent 2000 or more_n          -2.039443e-08 -3.776859e-09},
#   'transportationtype_workers': {'Rsquared': 0.25243947980218306,
#    'coefficients': transportation car_n           -8.327068e-08
#    transportation public_n         1.834310e-07
#    tranportation motorcycle_n     -3.528650e-06
#    Transportation Other means_n   -3.637611e-08
#    dtype: float64,
#    'interval':                                        min           max
#    transportation car_n         -1.151091e-07 -5.143228e-08
#    transportation public_n       1.218537e-07  2.450083e-07
#    tranportation motorcycle_n   -5.144571e-06 -1.912729e-06
#    Transportation Other means_n -8.270917e-08  9.956947e-09},
#   'typeof_household_workers': {}},
#  'Broken Muni Meter': {'age_workers': {'Rsquared': 0.68884688058725518,
#    'coefficients': population between 18 and 34_n    4.688220e-07
#    population between 35 to 64_n    -6.587544e-07
#    population 65 and over_n          1.368239e-06
#    dtype: float64,
#    'interval':                                          min           max
#    population between 18 and 34_n -1.939023e-07  1.131546e-06
#    population between 35 to 64_n  -1.734914e-06  4.174055e-07
#    population 65 and over_n       -1.106136e-06  3.842614e-06},
#   'education_workers': {'Rsquared': 0.72084027013973784,
#    'coefficients': population education high school_n    2.183275e-07
#    population education bachelors_n      4.096193e-06
#    population education masters_n       -1.136484e-05
#    population education phd_n            2.477199e-05
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n -1.366967e-07  5.733517e-07
#    population education bachelors_n    1.476448e-06  6.715938e-06
#    population education masters_n     -1.696292e-05 -5.766750e-06
#    population education phd_n          1.448899e-05  3.505498e-05},
#   'housing_values_workers': {'Rsquared': 0.70750600879487602,
#    'coefficients': house value for 20 to 100_n     3.212760e-06
#    house value for 100 to 500_n   -3.522047e-07
#    house value 500 or more_n       4.510123e-08
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n   1.492646e-06  4.932874e-06
#    house value for 100 to 500_n -5.907700e-07 -1.136393e-07
#    house value 500 or more_n    -6.333245e-08  1.535349e-07},
#   'income_workers': {'Rsquared': 0.70193245997117648,
#    'coefficients': household income form 10 to 40_n    7.910930e-07
#    household income form 40 to 75_n   -8.989788e-07
#    household income 75 and above_n     4.485294e-08
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n  7.939634e-08  1.502790e-06
#    household income form 40 to 75_n -1.971325e-06  1.733671e-07
#    household income 75 and above_n  -7.658777e-08  1.662936e-07},
#   'ownorrent_workers': {'Rsquared': 0.7157574531681079,
#    'coefficients': owner  occupied units_n   -3.544602e-07
#    renter occupied units_n    3.320413e-07
#    dtype: float64,
#    'interval':                                   min           max
#    owner  occupied units_n -5.448321e-07 -1.640883e-07
#    renter occupied units_n  2.091583e-07  4.549243e-07},
#   'race_workers': {'Rsquared': 0.74735647112673109,
#    'coefficients': Population white_n      -2.239877e-07
#    population black_n      -3.668698e-07
#    Population asian_n       9.939541e-07
#    population hispanic_n    7.187518e-07
#    population other _n     -2.651724e-06
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -3.710183e-07 -7.695711e-08
#    population black_n    -5.762171e-07 -1.575225e-07
#    Population asian_n     4.321415e-07  1.555767e-06
#    population hispanic_n  4.221551e-07  1.015348e-06
#    population other _n   -7.148448e-06  1.844999e-06},
#   'rent_workers': {'Rsquared': 0.68798897054472052,
#    'coefficients': rent bewteen 300 and 1000_n     2.854167e-07
#    rent bewteen 1000 and 2000_n   -4.548863e-08
#    rent 2000 or more_n             1.612415e-08
#    dtype: float64,
#    'interval':                                        min           max
#    rent bewteen 300 and 1000_n  -2.414914e-07  8.123249e-07
#    rent bewteen 1000 and 2000_n -3.383455e-07  2.473683e-07
#    rent 2000 or more_n          -1.240662e-07  1.563145e-07},
#   'transportationtype_workers': {'Rsquared': 0.74125630382919772,
#    'coefficients': transportation car_n           -1.564506e-06
#    transportation public_n         3.207144e-06
#    tranportation motorcycle_n     -5.123939e-05
#    Transportation Other means_n   -2.276280e-07
#    dtype: float64,
#    'interval':                                        min           max
#    transportation car_n         -2.073465e-06 -1.055547e-06
#    transportation public_n       2.223524e-06  4.190765e-06
#    tranportation motorcycle_n   -7.693968e-05 -2.553910e-05
#    Transportation Other means_n -9.621995e-07  5.069434e-07},
#   'typeof_household_workers': {'Rsquared': 0.68587347194649873,
#    'coefficients': family households_n       3.326392e-08
#    nonfamily households_n    8.969672e-08
#    dtype: float64,
#    'interval':                                  min           max
#    family households_n    -6.213803e-08  1.286659e-07
#    nonfamily households_n -5.005866e-08  2.294521e-07}},
#  'Broken Parking Meter': {'age_workers': {'Rsquared': 0.3560471272496365,
#    'coefficients': population between 18 and 34_n   -1.710664e-09
#    population between 35 to 64_n    -4.815689e-10
#    population 65 and over_n          6.171206e-09
#    dtype: float64,
#    'interval':                                          min           max
#    population between 18 and 34_n -9.657251e-09  6.235923e-09
#    population between 35 to 64_n  -1.377698e-08  1.281384e-08
#    population 65 and over_n       -2.486801e-08  3.721042e-08},
#   'education_workers': {'Rsquared': 0.47646915590895866,
#    'coefficients': population education high school_n    3.188618e-09
#    population education bachelors_n      2.451968e-08
#    population education masters_n       -7.864676e-08
#    population education phd_n            1.897089e-07
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n -7.724361e-10  7.149673e-09
#    population education bachelors_n   -5.705001e-09  5.474436e-08
#    population education masters_n     -1.437144e-07 -1.357910e-08
#    population education phd_n          7.358065e-08  3.058372e-07},
#   'housing_values_workers': {'Rsquared': 0.42956910544549665,
#    'coefficients': house value for 20 to 100_n     2.790091e-08
#    house value for 100 to 500_n   -1.958840e-09
#    house value 500 or more_n      -1.299084e-09
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n   2.810806e-09  5.299100e-08
#    house value for 100 to 500_n -5.192474e-09  1.274794e-09
#    house value 500 or more_n    -2.638814e-09  4.064561e-11},
#   'income_workers': {'Rsquared': 0.39014371886625221,
#    'coefficients': household income form 10 to 40_n    1.980710e-09
#    household income form 40 to 75_n   -7.791378e-10
#    household income 75 and above_n    -5.315939e-10
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n -7.786032e-09  1.174745e-08
#    household income form 40 to 75_n -1.533681e-08  1.377853e-08
#    household income 75 and above_n  -2.081357e-09  1.018170e-09},
#   'ownorrent_workers': {'Rsquared': 0.36843827382280514,
#    'coefficients': owner  occupied units_n   -1.430801e-09
#    renter occupied units_n    1.241041e-09
#    dtype: float64,
#    'interval':                                   min           max
#    owner  occupied units_n -3.965363e-09  1.103762e-09
#    renter occupied units_n -3.964255e-10  2.878508e-09},
#   'race_workers': {'Rsquared': 0.44772332721966812,
#    'coefficients': Population white_n      -1.409985e-09
#    population black_n      -9.027025e-10
#    Population asian_n       3.606851e-09
#    population hispanic_n    4.951056e-09
#    population other _n     -2.451276e-08
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -3.538032e-09  7.180631e-10
#    population black_n    -3.669615e-09  1.864210e-09
#    Population asian_n    -4.073025e-09  1.128673e-08
#    population hispanic_n  3.136711e-10  9.588441e-09
#    population other _n   -9.809080e-08  4.906527e-08},
#   'rent_workers': {'Rsquared': 0.38255375306546002,
#    'coefficients': rent bewteen 300 and 1000_n    -1.738348e-09
#    rent bewteen 1000 and 2000_n    1.759652e-09
#    rent 2000 or more_n            -1.250925e-09
#    dtype: float64,
#    'interval':                                        min           max
#    rent bewteen 300 and 1000_n  -8.619717e-09  5.143021e-09
#    rent bewteen 1000 and 2000_n -2.078299e-09  5.597602e-09
#    rent 2000 or more_n          -2.923105e-09  4.212560e-10},
#   'transportationtype_workers': {'Rsquared': 0.48982791380481761,
#    'coefficients': transportation car_n           -1.072501e-08
#    transportation public_n         2.395489e-08
#    tranportation motorcycle_n     -5.540450e-07
#    Transportation Other means_n   -5.915589e-10
#    dtype: float64,
#    'interval':                                        min           max
#    transportation car_n         -1.740193e-08 -4.048094e-09
#    transportation public_n       1.105097e-08  3.685881e-08
#    tranportation motorcycle_n   -8.727747e-07 -2.353153e-07
#    Transportation Other means_n -9.007205e-09  7.824087e-09},
#   'typeof_household_workers': {'Rsquared': 0.36519539910496501,
#    'coefficients': family households_n       8.396772e-10
#    nonfamily households_n   -8.035771e-10
#    dtype: float64,
#    'interval':                                  min           max
#    family households_n    -2.871828e-10  1.966537e-09
#    nonfamily households_n -2.448518e-09  8.413640e-10}},
#  'Building/Use': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Bus Stop Shelter Placement': {'age_workers': {},
#   'education_workers': {'Rsquared': 0.3007567846591086,
#    'coefficients': population education high school_n    8.004812e-09
#    population education bachelors_n      2.923408e-08
#    population education masters_n       -1.100736e-07
#    population education phd_n            2.855268e-07
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n  2.963123e-10  1.571331e-08
#    population education bachelors_n   -2.421457e-08  8.268274e-08
#    population education masters_n     -2.209951e-07  8.478201e-10
#    population education phd_n          7.051248e-08  5.005411e-07},
#   'housing_values_workers': {'Rsquared': 0.24355336125497706,
#    'coefficients': house value for 20 to 100_n     6.307872e-09
#    house value for 100 to 500_n    2.857299e-09
#    house value 500 or more_n      -3.007492e-09
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n  -2.083298e-08  3.344872e-08
#    house value for 100 to 500_n -8.043256e-10  6.518923e-09
#    house value 500 or more_n    -4.964730e-09 -1.050254e-09},
#   'income_workers': {'Rsquared': 0.27611356349260152,
#    'coefficients': household income form 10 to 40_n   -6.934733e-09
#    household income form 40 to 75_n    1.643989e-08
#    household income 75 and above_n    -3.646516e-09
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n -1.968488e-08  5.815413e-09
#    household income form 40 to 75_n -3.638560e-09  3.651834e-08
#    household income 75 and above_n  -6.209697e-09 -1.083335e-09},
#   'ownorrent_workers': {},
#   'race_workers': {'Rsquared': 0.2780662106911137,
#    'coefficients': Population white_n      -1.242397e-09
#    population black_n       1.086002e-09
#    Population asian_n      -1.335648e-09
#    population hispanic_n    7.955540e-09
#    population other _n     -4.393870e-08
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -3.525310e-09  1.040516e-09
#    population black_n    -2.515756e-09  4.687760e-09
#    Population asian_n    -1.228847e-08  9.617178e-09
#    population hispanic_n  2.907586e-09  1.300349e-08
#    population other _n   -1.085930e-07  2.071564e-08},
#   'rent_workers': {'Rsquared': 0.29040238661521434,
#    'coefficients': rent bewteen 300 and 1000_n    -6.340980e-09
#    rent bewteen 1000 and 2000_n    5.687220e-09
#    rent 2000 or more_n            -4.894797e-09
#    dtype: float64,
#    'interval':                                        min           max
#    rent bewteen 300 and 1000_n  -1.389552e-08  1.213561e-09
#    rent bewteen 1000 and 2000_n  1.466320e-09  9.908120e-09
#    rent 2000 or more_n          -7.365655e-09 -2.423938e-09},
#   'transportationtype_workers': {'Rsquared': 0.26938645694811547,
#    'coefficients': transportation car_n           -6.847502e-09
#    transportation public_n         2.251156e-08
#    tranportation motorcycle_n     -4.974813e-07
#    Transportation Other means_n   -1.067325e-08
#    dtype: float64,
#    'interval':                                        min           max
#    transportation car_n         -1.455662e-08  8.616180e-10
#    transportation public_n       7.898086e-09  3.712504e-08
#    tranportation motorcycle_n   -8.951153e-07 -9.984738e-08
#    Transportation Other means_n -2.554502e-08  4.198522e-09},
#   'typeof_household_workers': {'Rsquared': 0.23134625399817788,
#    'coefficients': family households_n       2.860060e-09
#    nonfamily households_n   -3.714889e-09
#    dtype: float64,
#    'interval':                                  min           max
#    family households_n     1.196326e-09  4.523795e-09
#    nonfamily households_n -6.252514e-09 -1.177264e-09}},
#  'CONSTRUCTION': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {'Rsquared': 0.22027885154788818,
#    'coefficients': Population white_n       7.364606e-10
#    population black_n       6.160955e-09
#    Population asian_n       3.149689e-09
#    population hispanic_n    9.667923e-09
#    population other _n     -1.476633e-07
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -4.393032e-09  5.865953e-09
#    population black_n     3.231584e-10  1.199875e-08
#    Population asian_n    -2.076955e-08  2.706892e-08
#    population hispanic_n  2.464360e-09  1.687149e-08
#    population other _n   -2.877772e-07 -7.549477e-09},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'City Vehicle Placard Complaint': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Collection Truck Noise': {'age_workers': {},
#   'education_workers': {'Rsquared': 0.20559355483357222,
#    'coefficients': population education high school_n    6.932456e-09
#    population education bachelors_n      7.855592e-09
#    population education masters_n       -5.305543e-08
#    population education phd_n            1.877644e-07
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n  1.670417e-09  1.219450e-08
#    population education bachelors_n   -3.366773e-08  4.937891e-08
#    population education masters_n     -1.421738e-07  3.606293e-08
#    population education phd_n          3.162596e-08  3.439028e-07},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Construction': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Consumer Complaint': {'age_workers': {'Rsquared': 0.43663340652251892,
#    'coefficients': population between 18 and 34_n   -2.394239e-07
#    population between 35 to 64_n     5.248331e-07
#    population 65 and over_n         -9.425877e-07
#    dtype: float64,
#    'interval':                                          min           max
#    population between 18 and 34_n -7.201039e-07  2.412560e-07
#    population between 35 to 64_n  -2.594852e-07  1.309151e-06
#    population 65 and over_n       -2.752901e-06  8.677255e-07},
#   'education_workers': {'Rsquared': 0.44944376947029718,
#    'coefficients': population education high school_n    7.773281e-08
#    population education bachelors_n      1.855409e-06
#    population education masters_n       -4.499084e-06
#    population education phd_n            6.959395e-06
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n -1.934275e-07  3.488931e-07
#    population education bachelors_n   -1.459342e-07  3.856751e-06
#    population education masters_n     -8.776024e-06 -2.221432e-07
#    population education phd_n         -9.086430e-07  1.482743e-05},
#   'housing_values_workers': {'Rsquared': 0.44235427702164254,
#    'coefficients': house value for 20 to 100_n     3.990936e-07
#    house value for 100 to 500_n    5.881664e-08
#    house value 500 or more_n      -5.222332e-08
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n  -8.680043e-07  1.666191e-06
#    house value for 100 to 500_n -1.155619e-07  2.331952e-07
#    house value 500 or more_n    -1.334691e-07  2.902245e-08},
#   'income_workers': {'Rsquared': 0.44756986401000454,
#    'coefficients': household income form 10 to 40_n    4.565431e-07
#    household income form 40 to 75_n   -5.167066e-07
#    household income 75 and above_n     1.655825e-08
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n -6.972203e-08  9.828081e-07
#    household income form 40 to 75_n -1.309777e-06  2.763639e-07
#    household income 75 and above_n  -7.337335e-08  1.064899e-07},
#   'ownorrent_workers': {'Rsquared': 0.43377583886213256,
#    'coefficients': owner  occupied units_n   -2.888831e-08
#    renter occupied units_n    6.509750e-08
#    dtype: float64,
#    'interval':                                   min           max
#    owner  occupied units_n -1.712079e-07  1.134313e-07
#    renter occupied units_n -2.680767e-08  1.570027e-07},
#   'race_workers': {'Rsquared': 0.46679335861655213,
#    'coefficients': Population white_n      -1.393219e-07
#    population black_n      -1.259620e-07
#    Population asian_n       3.069725e-07
#    population hispanic_n    2.560175e-07
#    population other _n      4.662452e-07
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -2.547262e-07 -2.391758e-08
#    population black_n    -2.913385e-07  3.941449e-08
#    Population asian_n    -1.379126e-07  7.518575e-07
#    population hispanic_n  2.179729e-08  4.902378e-07
#    population other _n   -3.072513e-06  4.005003e-06},
#   'rent_workers': {'Rsquared': 0.44124654073753267,
#    'coefficients': rent bewteen 300 and 1000_n    -1.905312e-07
#    rent bewteen 1000 and 2000_n    1.724521e-07
#    rent 2000 or more_n            -6.015258e-08
#    dtype: float64,
#    'interval':                                        min           max
#    rent bewteen 300 and 1000_n  -5.745247e-07  1.934623e-07
#    rent bewteen 1000 and 2000_n -4.102103e-08  3.859252e-07
#    rent 2000 or more_n          -1.623176e-07  4.201243e-08},
#   'transportationtype_workers': {'Rsquared': 0.45331099272702347,
#    'coefficients': transportation car_n           -2.790131e-07
#    transportation public_n         8.482620e-07
#    tranportation motorcycle_n     -2.802380e-05
#    Transportation Other means_n    2.239142e-07
#    dtype: float64,
#    'interval':                                        min           max
#    transportation car_n         -6.659501e-07  1.079238e-07
#    transportation public_n       9.300871e-08  1.603515e-06
#    tranportation motorcycle_n   -4.818620e-05 -7.861408e-06
#    Transportation Other means_n -3.584964e-07  8.063249e-07},
#   'typeof_household_workers': {'Rsquared': 0.43802159591362411,
#    'coefficients': family households_n       7.634063e-08
#    nonfamily households_n   -4.977873e-08
#    dtype: float64,
#    'interval':                                  min           max
#    family households_n     7.148561e-09  1.455327e-07
#    nonfamily households_n -1.511650e-07  5.160754e-08}},
#  'Cranes and Derricks': {'age_workers': {'Rsquared': 0.36891516803594782,
#    'coefficients': population between 18 and 34_n   -1.069513e-08
#    population between 35 to 64_n     2.837224e-08
#    population 65 and over_n         -5.929971e-08
#    dtype: float64,
#    'interval':                                          min           max
#    population between 18 and 34_n -4.277683e-08  2.138657e-08
#    population between 35 to 64_n  -2.469571e-08  8.144018e-08
#    population 65 and over_n       -1.802526e-07  6.165320e-08},
#   'education_workers': {'Rsquared': 0.36811848943633052,
#    'coefficients': population education high school_n    3.517374e-09
#    population education bachelors_n      2.342112e-08
#    population education masters_n       -4.771070e-08
#    population education phd_n            2.404492e-08
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n -2.304220e-08  3.007695e-08
#    population education bachelors_n   -1.245319e-07  1.713742e-07
#    population education masters_n     -3.234891e-07  2.280677e-07
#    population education phd_n         -6.512672e-07  6.993571e-07},
#   'housing_values_workers': {'Rsquared': 0.37181750133496549,
#    'coefficients': house value for 20 to 100_n    -7.683388e-09
#    house value for 100 to 500_n    5.177242e-09
#    house value 500 or more_n      -2.227624e-09
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n  -1.045842e-07  8.921738e-08
#    house value for 100 to 500_n -7.696743e-09  1.805123e-08
#    house value 500 or more_n    -7.792268e-09  3.337020e-09},
#   'income_workers': {'Rsquared': 0.36605093601882488,
#    'coefficients': household income form 10 to 40_n   -5.697628e-09
#    household income form 40 to 75_n    1.388016e-08
#    household income 75 and above_n    -2.389062e-09
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n -4.435011e-08  3.295486e-08
#    household income form 40 to 75_n -4.364159e-08  7.140190e-08
#    household income 75 and above_n  -8.524937e-09  3.746813e-09},
#   'ownorrent_workers': {'Rsquared': 0.35927372651340106,
#    'coefficients': owner  occupied units_n    1.340051e-09
#    renter occupied units_n    5.850698e-10
#    dtype: float64,
#    'interval':                                   min           max
#    owner  occupied units_n -8.531059e-09  1.121116e-08
#    renter occupied units_n -5.789591e-09  6.959731e-09},
#   'race_workers': {'Rsquared': 0.38134705682890047,
#    'coefficients': Population white_n      -7.409534e-10
#    population black_n       5.136220e-09
#    Population asian_n      -1.086298e-08
#    population hispanic_n   -3.276695e-09
#    population other _n      8.875772e-08
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -1.016708e-08  8.685174e-09
#    population black_n    -7.147426e-09  1.741987e-08
#    Population asian_n    -4.287633e-08  2.115038e-08
#    population hispanic_n -2.061737e-08  1.406398e-08
#    population other _n   -2.112754e-07  3.887908e-07},
#   'rent_workers': {'Rsquared': 0.36607864078210617,
#    'coefficients': rent bewteen 300 and 1000_n    -2.543187e-09
#    rent bewteen 1000 and 2000_n    3.789373e-09
#    rent 2000 or more_n            -2.247647e-09
#    dtype: float64,
#    'interval':                                        min           max
#    rent bewteen 300 and 1000_n  -3.002783e-08  2.494146e-08
#    rent bewteen 1000 and 2000_n -1.178432e-08  1.936307e-08
#    rent 2000 or more_n          -9.181070e-09  4.685777e-09},
#   'transportationtype_workers': {'Rsquared': 0.36554441199929977,
#    'coefficients': transportation car_n           -1.808223e-09
#    transportation public_n         1.380536e-08
#    tranportation motorcycle_n     -2.687542e-07
#    Transportation Other means_n   -7.701337e-09
#    dtype: float64,
#    'interval':                                        min           max
#    transportation car_n         -3.066725e-08  2.705080e-08
#    transportation public_n      -4.165685e-08  6.926757e-08
#    tranportation motorcycle_n   -1.659156e-06  1.121647e-06
#    Transportation Other means_n -4.409116e-08  2.868849e-08},
#   'typeof_household_workers': {'Rsquared': 0.36604045097405169,
#    'coefficients': family households_n       2.798297e-09
#    nonfamily households_n   -2.151616e-09
#    dtype: float64,
#    'interval':                                  min           max
#    family households_n    -1.754252e-09  7.350845e-09
#    nonfamily households_n -8.796027e-09  4.492795e-09}},
#  'Curb Condition': {'age_workers': {},
#   'education_workers': {'Rsquared': 0.20360293041522437,
#    'coefficients': population education high school_n    1.128928e-08
#    population education bachelors_n      1.901217e-07
#    population education masters_n       -4.873648e-07
#    population education phd_n            7.224363e-07
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n -6.690574e-09  2.926914e-08
#    population education bachelors_n    5.442773e-08  3.258157e-07
#    population education masters_n     -7.778500e-07 -1.968795e-07
#    population education phd_n          1.976593e-07  1.247213e-06},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {'Rsquared': 0.22768378460965011,
#    'coefficients': rent bewteen 300 and 1000_n    -4.517403e-08
#    rent bewteen 1000 and 2000_n    3.181285e-08
#    rent 2000 or more_n            -1.835018e-08
#    dtype: float64,
#    'interval':                                        min           max
#    rent bewteen 300 and 1000_n  -7.063642e-08 -1.971163e-08
#    rent bewteen 1000 and 2000_n  1.773242e-08  4.589328e-08
#    rent 2000 or more_n          -2.502783e-08 -1.167253e-08},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'DOOR/WINDOW': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {'Rsquared': 0.21397689213918802,
#    'coefficients': house value for 20 to 100_n     4.115079e-06
#    house value for 100 to 500_n   -2.311413e-07
#    house value 500 or more_n      -2.861878e-07
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n   2.429046e-06  5.801112e-06
#    house value for 100 to 500_n -4.639536e-07  1.671019e-09
#    house value 500 or more_n    -3.933749e-07 -1.790007e-07},
#   'income_workers': {'Rsquared': 0.20628872925349795,
#    'coefficients': household income form 10 to 40_n    1.353447e-06
#    household income form 40 to 75_n   -1.608574e-06
#    household income 75 and above_n     6.826231e-09
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n  6.488110e-07  2.058082e-06
#    household income form 40 to 75_n -2.670482e-06 -5.466664e-07
#    household income 75 and above_n  -1.133930e-07  1.270454e-07},
#   'ownorrent_workers': {},
#   'race_workers': {'Rsquared': 0.26356896705691568,
#    'coefficients': Population white_n      -1.234599e-07
#    population black_n       9.646458e-08
#    Population asian_n      -1.851777e-07
#    population hispanic_n    8.474715e-07
#    population other _n     -5.092863e-06
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -2.743991e-07  2.747934e-08
#    population black_n    -1.192979e-07  3.122270e-07
#    Population asian_n    -7.656471e-07  3.952918e-07
#    population hispanic_n  5.408473e-07  1.154096e-06
#    population other _n   -9.721985e-06 -4.637403e-07},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'DPR Internal': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Damaged Tree': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Dead Tree': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Derelict Bicycle': {'age_workers': {'Rsquared': 0.31940959001904168,
#    'coefficients': population between 18 and 34_n   -1.617827e-08
#    population between 35 to 64_n     1.765925e-07
#    population 65 and over_n         -4.959903e-07
#    dtype: float64,
#    'interval':                                          min           max
#    population between 18 and 34_n -9.078444e-08  5.842790e-08
#    population between 35 to 64_n   5.787749e-08  2.953075e-07
#    population 65 and over_n       -7.684470e-07 -2.235335e-07},
#   'education_workers': {'Rsquared': 0.39981932101599738,
#    'coefficients': population education high school_n    2.504370e-09
#    population education bachelors_n      5.004553e-07
#    population education masters_n       -1.130649e-06
#    population education phd_n            1.205774e-06
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n -3.658745e-08  4.159619e-08
#    population education bachelors_n    2.117656e-07  7.891451e-07
#    population education masters_n     -1.752030e-06 -5.092678e-07
#    population education phd_n          6.289249e-08  2.348656e-06},
#   'housing_values_workers': {'Rsquared': 0.26587458357560267,
#    'coefficients': house value for 20 to 100_n     2.723651e-07
#    house value for 100 to 500_n   -1.951090e-08
#    house value 500 or more_n      -1.233282e-08
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n   1.849690e-08  5.262332e-07
#    house value for 100 to 500_n -5.163787e-08  1.261606e-08
#    house value 500 or more_n    -2.653967e-08  1.874036e-09},
#   'income_workers': {'Rsquared': 0.36443476168350708,
#    'coefficients': household income form 10 to 40_n   -5.616801e-09
#    household income form 40 to 75_n    5.133771e-08
#    household income 75 and above_n    -1.874490e-08
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n -9.185249e-08  8.061889e-08
# ...
#    'coefficients': transportation car_n           -0.000003
#    transportation public_n         0.000006
#    tranportation motorcycle_n     -0.000121
#    Transportation Other means_n   -0.000002
#    dtype: float64,
#    'interval':                                    min           max
#    transportation car_n         -0.000004 -1.580891e-06
#    transportation public_n       0.000004  8.130612e-06
#    tranportation motorcycle_n   -0.000174 -6.663685e-05
#    Transportation Other means_n -0.000003 -1.128520e-07},
#   'typeof_household_workers': {}},
#  'Unleashed Dog': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Unsanitary Animal Facility': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Unsanitary Animal Pvt Property': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Unsanitary Pigeon Condition': {'age_workers': {},
#   'education_workers': {'Rsquared': 0.29206555582114002,
#    'coefficients': population education high school_n    1.126335e-08
#    population education bachelors_n      7.625938e-08
#    population education masters_n       -2.296322e-07
#    population education phd_n            4.539949e-07
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n  2.969461e-09  1.955723e-08
#    population education bachelors_n    1.377497e-08  1.387438e-07
#    population education masters_n     -3.628542e-07 -9.641018e-08
#    population education phd_n          2.122283e-07  6.957616e-07},
#   'housing_values_workers': {},
#   'income_workers': {'Rsquared': 0.23455426882198749,
#    'coefficients': household income form 10 to 40_n    1.286448e-09
#    household income form 40 to 75_n    8.806382e-09
#    household income 75 and above_n    -4.455127e-09
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n -1.718124e-08  1.975413e-08
#    household income form 40 to 75_n -1.867649e-08  3.628925e-08
#    household income 75 and above_n  -7.440303e-09 -1.469952e-09},
#   'ownorrent_workers': {},
#   'race_workers': {'Rsquared': 0.2535614905065332,
#    'coefficients': Population white_n      -5.590422e-09
#    population black_n       6.297715e-10
#    Population asian_n       1.139815e-08
#    population hispanic_n    1.407193e-08
#    population other _n     -7.692635e-08
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -9.401709e-09 -1.779134e-09
#    population black_n    -4.794026e-09  6.053569e-09
#    Population asian_n    -3.720997e-09  2.651729e-08
#    population hispanic_n  5.739276e-09  2.240459e-08
#    population other _n   -1.955867e-07  4.173404e-08},
#   'rent_workers': {'Rsquared': 0.22550123623985519,
#    'coefficients': rent bewteen 300 and 1000_n    -3.149913e-09
#    rent bewteen 1000 and 2000_n    5.560457e-09
#    rent 2000 or more_n            -8.085270e-09
#    dtype: float64,
#    'interval':                                        min           max
#    rent bewteen 300 and 1000_n  -1.809838e-08  1.179856e-08
#    rent bewteen 1000 and 2000_n -2.473718e-09  1.359463e-08
#    rent 2000 or more_n          -1.136386e-08 -4.806676e-09},
#   'transportationtype_workers': {'Rsquared': 0.20860570582266602,
#    'coefficients': transportation car_n           -1.506661e-08
#    transportation public_n         4.439786e-08
#    tranportation motorcycle_n     -7.323800e-07
#    Transportation Other means_n   -2.779976e-08
#    dtype: float64,
#    'interval':                                        min           max
#    transportation car_n         -2.863332e-08 -1.499888e-09
#    transportation public_n       1.791052e-08  7.088520e-08
#    tranportation motorcycle_n   -1.439244e-06 -2.551579e-08
#    Transportation Other means_n -4.891880e-08 -6.680710e-09},
#   'typeof_household_workers': {}},
#  'Urinating in Public': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Vacant Lot': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Vending': {'age_workers': {'Rsquared': 0.48607030353609537,
#    'coefficients': population between 18 and 34_n    7.076332e-08
#    population between 35 to 64_n    -5.591067e-08
#    population 65 and over_n          7.438458e-08
#    dtype: float64,
#    'interval':                                          min           max
#    population between 18 and 34_n -9.105338e-08  2.325800e-07
#    population between 35 to 64_n  -3.169554e-07  2.051341e-07
#    population 65 and over_n       -5.259567e-07  6.747259e-07},
#   'education_workers': {'Rsquared': 0.48979104366379,
#    'coefficients': population education high school_n    2.356948e-08
#    population education bachelors_n      1.103938e-09
#    population education masters_n       -1.052773e-07
#    population education phd_n            9.721547e-07
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n -6.723163e-08  1.143706e-07
#    population education bachelors_n   -6.684742e-07  6.706821e-07
#    population education masters_n     -1.536632e-06  1.326077e-06
#    population education phd_n         -1.659793e-06  3.604102e-06},
#   'housing_values_workers': {'Rsquared': 0.49444135163254255,
#    'coefficients': house value for 20 to 100_n     3.665559e-07
#    house value for 100 to 500_n   -4.581252e-08
#    house value 500 or more_n       1.516830e-08
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n  -5.837467e-08  7.914864e-07
#    house value for 100 to 500_n -1.046201e-07  1.299506e-08
#    house value 500 or more_n    -1.168716e-08  4.202376e-08},
#   'income_workers': {'Rsquared': 0.50869299908124366,
#    'coefficients': household income form 10 to 40_n    2.402214e-07
#    household income form 40 to 75_n   -3.478840e-07
#    household income 75 and above_n     3.869842e-08
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n  6.244265e-08  4.180002e-07
#    household income form 40 to 75_n -6.154176e-07 -8.035039e-08
#    household income 75 and above_n   8.705283e-09  6.869156e-08},
#   'ownorrent_workers': {'Rsquared': 0.49221152003639546,
#    'coefficients': owner  occupied units_n   -3.081557e-08
#    renter occupied units_n    3.580844e-08
#    dtype: float64,
#    'interval':                                   min           max
#    owner  occupied units_n -7.861698e-08  1.698585e-08
#    renter occupied units_n  4.950033e-09  6.666686e-08},
#   'race_workers': {'Rsquared': 0.51015777027554743,
#    'coefficients': Population white_n      -9.155670e-09
#    population black_n      -6.298593e-08
#    Population asian_n       3.219239e-08
#    population hispanic_n    9.769124e-08
#    population other _n     -1.240394e-07
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -4.836187e-08  3.005053e-08
#    population black_n    -1.182789e-07 -7.692912e-09
#    Population asian_n    -1.164491e-07  1.808339e-07
#    population hispanic_n  1.957410e-08  1.758084e-07
#    population other _n   -1.313693e-06  1.065614e-06},
#   'rent_workers': {'Rsquared': 0.48980006208360494,
#    'coefficients': rent bewteen 300 and 1000_n     5.575552e-08
#    rent bewteen 1000 and 2000_n   -2.485702e-08
#    rent 2000 or more_n             3.060681e-08
#    dtype: float64,
#    'interval':                                        min           max
#    rent bewteen 300 and 1000_n  -7.314940e-08  1.846604e-07
#    rent bewteen 1000 and 2000_n -9.657830e-08  4.686426e-08
#    rent 2000 or more_n          -3.390741e-09  6.460436e-08},
#   'transportationtype_workers': {'Rsquared': 0.49988226548270709,
#    'coefficients': transportation car_n           -1.095255e-07
#    transportation public_n         2.269944e-07
#    tranportation motorcycle_n     -5.958609e-06
#    Transportation Other means_n    1.261229e-07
#    dtype: float64,
#    'interval':                                        min           max
#    transportation car_n         -2.410039e-07  2.195299e-08
#    transportation public_n      -2.861348e-08  4.826023e-07
#    tranportation motorcycle_n   -1.268572e-05  7.685051e-07
#    Transportation Other means_n -6.750486e-08  3.197506e-07},
#   'typeof_household_workers': {'Rsquared': 0.48931351433646753,
#    'coefficients': family households_n      -6.215483e-09
#    nonfamily households_n    3.045542e-08
#    dtype: float64,
#    'interval':                                  min           max
#    family households_n    -2.923510e-08  1.680414e-08
#    nonfamily households_n -3.263279e-09  6.417412e-08}},
#  'Violation of Park Rules': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'WATER LEAK': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {'Rsquared': 0.20246580856684726,
#    'coefficients': house value for 20 to 100_n     3.844798e-06
#    house value for 100 to 500_n   -2.041246e-07
#    house value 500 or more_n      -2.774566e-07
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n   2.190403e-06  5.499193e-06
#    house value for 100 to 500_n -4.318232e-07  2.357396e-08
#    house value 500 or more_n    -3.835254e-07 -1.713878e-07},
#   'income_workers': {'Rsquared': 0.20208017314364779,
#    'coefficients': household income form 10 to 40_n    1.241988e-06
#    household income form 40 to 75_n   -1.441636e-06
#    household income 75 and above_n    -9.015911e-09
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n  5.514812e-07  1.932495e-06
#    household income form 40 to 75_n -2.482257e-06 -4.010151e-07
#    household income 75 and above_n  -1.270274e-07  1.089956e-07},
#   'ownorrent_workers': {},
#   'race_workers': {'Rsquared': 0.24813598912312451,
#    'coefficients': Population white_n      -1.222900e-07
#    population black_n       1.215444e-07
#    Population asian_n      -7.947072e-08
#    population hispanic_n    7.790277e-07
#    population other _n     -5.145554e-06
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -2.719350e-07  2.735505e-08
#    population black_n    -9.284710e-08  3.359358e-07
#    Population asian_n    -6.562041e-07  4.972626e-07
#    population hispanic_n  4.753886e-07  1.082667e-06
#    population other _n   -9.732810e-06 -5.582984e-07},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Water Conservation': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}},
#  'Water Quality': {'age_workers': {},
#   'education_workers': {'Rsquared': 0.28158568133264172,
#    'coefficients': population education high school_n    2.423863e-08
#    population education bachelors_n      6.846085e-08
#    population education masters_n       -2.667548e-07
#    population education phd_n            6.832820e-07
#    dtype: float64,
#    'interval':                                              min           max
#    population education high school_n  1.004092e-08  3.843634e-08
#    population education bachelors_n   -3.633561e-08  1.732573e-07
#    population education masters_n     -4.907109e-07 -4.279865e-08
#    population education phd_n          2.713809e-07  1.095183e-06},
#   'housing_values_workers': {'Rsquared': 0.22436506290348279,
#    'coefficients': house value for 20 to 100_n    -9.340815e-09
#    house value for 100 to 500_n    1.206497e-08
#    house value 500 or more_n      -8.800907e-09
#    dtype: float64,
#    'interval':                                        min           max
#    house value for 20 to 100_n  -7.818201e-08  5.950038e-08
#    house value for 100 to 500_n  2.609355e-09  2.152058e-08
#    house value 500 or more_n    -1.319495e-08 -4.406866e-09},
#   'income_workers': {'Rsquared': 0.24210410931944693,
#    'coefficients': household income form 10 to 40_n   -9.693096e-09
#    household income form 40 to 75_n    3.114762e-08
#    household income 75 and above_n    -8.368091e-09
#    dtype: float64,
#    'interval':                                            min           max
#    household income form 10 to 40_n -3.800017e-08  1.861398e-08
#    household income form 40 to 75_n -1.150302e-08  7.379825e-08
#    household income 75 and above_n  -1.320044e-08 -3.535740e-09},
#   'ownorrent_workers': {},
#   'race_workers': {'Rsquared': 0.22037258479813704,
#    'coefficients': Population white_n      -4.318733e-09
#    population black_n       5.726759e-09
#    Population asian_n       1.526578e-08
#    population hispanic_n    1.488721e-08
#    population other _n     -1.447840e-07
#    dtype: float64,
#    'interval':                                 min           max
#    Population white_n    -1.073920e-08  2.101736e-09
#    population black_n    -3.441731e-09  1.489525e-08
#    Population asian_n    -9.464553e-09  3.999610e-08
#    population hispanic_n  1.885880e-09  2.788854e-08
#    population other _n   -3.410777e-07  5.150972e-08},
#   'rent_workers': {'Rsquared': 0.25058441917118091,
#    'coefficients': rent bewteen 300 and 1000_n    -8.054552e-09
#    rent bewteen 1000 and 2000_n    1.100740e-08
#    rent 2000 or more_n            -1.340160e-08
#    dtype: float64,
#    'interval':                                        min           max
#    rent bewteen 300 and 1000_n  -2.854757e-08  1.243846e-08
#    rent bewteen 1000 and 2000_n -3.824481e-10  2.239725e-08
#    rent 2000 or more_n          -1.882562e-08 -7.977580e-09},
#   'transportationtype_workers': {'Rsquared': 0.22234643200073956,
#    'coefficients': transportation car_n           -5.556928e-09
#    transportation public_n         3.966930e-08
#    tranportation motorcycle_n     -7.307039e-07
#    Transportation Other means_n   -4.133515e-08
#    dtype: float64,
#    'interval':                                        min           max
#    transportation car_n         -2.675217e-08  1.563831e-08
#    transportation public_n      -1.705306e-09  8.104390e-08
#    tranportation motorcycle_n   -1.833886e-06  3.724780e-07
#    Transportation Other means_n -7.315677e-08 -9.513526e-09},
#   'typeof_household_workers': {'Rsquared': 0.23821547826141964,
#    'coefficients': family households_n       9.636640e-09
#    nonfamily households_n   -1.255419e-08
#    dtype: float64,
#    'interval':                                  min           max
#    family households_n     5.944800e-09  1.332848e-08
#    nonfamily households_n -1.796356e-08 -7.144818e-09}},
#  'Water System': {'age_workers': {},
#   'education_workers': {},
#   'housing_values_workers': {},
#   'income_workers': {},
#   'ownorrent_workers': {},
#   'race_workers': {},
#   'rent_workers': {},
#   'transportationtype_workers': {},
#   'typeof_household_workers': {}}}

# %%
#DUMPING THE DICTIONARY INTO A FRAME
a = pd.concat(map(pd.DataFrame, OLS_results_final.itervalues()), keys=OLS_results_final.keys()).stack().unstack(1).unstack(1)
a.columns = a.columns.droplevel(0)

# %%
#CREATING SEPARATE FRAMES FOR EACH GROUP OF DEMOGRAPHIC FEATURES 
dicframe = {}
for data_group in variable_groups_workers:
    c = pd.DataFrame(np.nan, index = eval(data_group), columns = [u'coefficient'])
    dicframe[data_group] = pd.DataFrame()
    for i in range (0, 71):
        d =  a[data_group][i]
        if d is None:
            dicframe[data_group] = pd.concat([dicframe[data_group] , c], axis=1, ignore_index=True)
        else:    
            dicframe[data_group] = pd.concat([dicframe[data_group] , d], axis=1, ignore_index=True)
    dicframe[data_group] = dicframe[data_group].T

# %%
#CREATING A COEFFICIENT FRAME
coefficients1 = pd.DataFrame()
for data_group in variable_groups_workers:
    coefficients1 = pd.concat([coefficients1, dicframe[data_group]], axis=1)

# %%
#sETTING THE FRAME'S INDEX AS THE TYPES OF COMPLAINTS
coefficients1 = coefficients1.set_index(a.index)

# %%
#STORING IT IN A CSV FOR VISUALIZATION
coefficients1.to_csv('OLS_workers_coefficients.csv')
